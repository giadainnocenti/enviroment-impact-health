# %%
import pandas as pd
import sqlite3
from sodapy import Socrata
from config import userID, key
import requests

# %%
#connecting to the sqlite database
conn = sqlite3.connect('health_air.db')

# %%
#function to add a table to the database
def add_table_to_db(table_name, df, connection_db):
    cur = conn.cursor()
    df.to_sql(name=table_name, if_exists='replace', con=conn)
    return(cur.execute("""SELECT * FROM asthma;""").fetchall())

# %% [markdown]
# # ETL of [Asthma data](https://chronicdata.cdc.gov/Chronic-Disease-Indicators/U-S-Chronic-Disease-Indicators-Asthma/us8e-ubyj)

# %%
# Instruction from the CDC website to extract data
# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("chronicdata.cdc.gov", None)

# Return as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get_all("us8e-ubyj")

# Convert to pandas DataFrame
asthma_df = pd.DataFrame.from_records(results)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
asthma_df
# Out:
#       yearstart yearend locationabbr locationdesc datasource   topic  \
# 0          2012    2012           AL      Alabama       NVSS  Asthma
# 1          2014    2014           AL      Alabama       NVSS  Asthma
# 2          2011    2011           AZ      Arizona       NVSS  Asthma
# 3          2015    2015           CT  Connecticut       NVSS  Asthma
# 4          2011    2011           FL      Florida       NVSS  Asthma
# ...         ...     ...          ...          ...        ...     ...
# 64714      2011    2011           WI    Wisconsin      BRFSS  Asthma
# 64715      2016    2016           TX        Texas      BRFSS  Asthma
# 64716      2019    2019           WI    Wisconsin      BRFSS  Asthma
# 64717      2014    2014           PR  Puerto Rico      BRFSS  Asthma
# 64718      2017    2017           WI    Wisconsin      BRFSS  Asthma
#
#                                                 question  \
# 0                                  Asthma mortality rate
# 1                                  Asthma mortality rate
# 2                                  Asthma mortality rate
# 3                                  Asthma mortality rate
# 4                                  Asthma mortality rate
# ...                                                  ...
# 64714  Pneumococcal vaccination among noninstitutiona...
# 64715  Pneumococcal vaccination among noninstitutiona...
# 64716  Pneumococcal vaccination among noninstitutiona...
# 64717  Pneumococcal vaccination among noninstitutiona...
# 64718  Pneumococcal vaccination among noninstitutiona...
#
#                  datavaluetype datavalue datavaluealt  ... topicid questionid  \
# 0                       Number        37           37  ...     AST     AST4_1
# 1                       Number        22           22  ...     AST     AST4_1
# 2                       Number        29           29  ...     AST     AST4_1
# 3                       Number        34           34  ...     AST     AST4_1
# 4                       Number        54           54  ...     AST     AST4_1
# ...                        ...       ...          ...  ...     ...        ...
# 64714  Age-adjusted Prevalence       NaN          NaN  ...     AST     AST6_2
# 64715  Age-adjusted Prevalence       NaN          NaN  ...     AST     AST6_2
# 64716  Age-adjusted Prevalence       NaN          NaN  ...     AST     AST6_2
# 64717         Crude Prevalence       NaN          NaN  ...     AST     AST6_2
# 64718  Age-adjusted Prevalence       NaN          NaN  ...     AST     AST6_2
#
#       datavaluetypeid stratificationcategoryid1 stratificationid1  \
# 0                NMBR                    GENDER              GENF
# 1                NMBR                    GENDER              GENM
# 2                NMBR                    GENDER              GENM
# 3                NMBR                    GENDER              GENF
# 4                NMBR                    GENDER              GENM
# ...               ...                       ...               ...
# 64714      AGEADJPREV                    GENDER              GENM
# 64715      AGEADJPREV                      RACE               MRC
# 64716      AGEADJPREV                      RACE               OTH
# 64717         CRDPREV                    GENDER              GENM
# 64718      AGEADJPREV                      RACE               BLK
#
#       datavalueunit lowconfidencelimit highconfidencelimit  \
# 0               NaN                NaN                 NaN
# 1               NaN                NaN                 NaN
# 2               NaN                NaN                 NaN
# 3               NaN                NaN                 NaN
# 4               NaN                NaN                 NaN
# ...             ...                ...                 ...
# 64714             %                NaN                 NaN
# 64715             %                NaN                 NaN
# 64716             %                NaN                 NaN
# 64717             %                NaN                 NaN
# 64718             %                NaN                 NaN
#
#       datavaluefootnotesymbol  \
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ...                       ...
# 64714                    ****
# 64715                    ****
# 64716                    ****
# 64717                    ****
# 64718                    ****
#
#                                        datavaluefootnote
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 64714  Sample size of denominator and/or age group fo...
# 64715  Sample size of denominator and/or age group fo...
# 64716  Sample size of denominator and/or age group fo...
# 64717  Sample size of denominator and/or age group fo...
# 64718  Sample size of denominator and/or age group fo...
#
# [64719 rows x 23 columns]

# %%
asthma_df.columns
# Out:
# Index(['yearstart', 'yearend', 'locationabbr', 'locationdesc', 'datasource',
#        'topic', 'question', 'datavaluetype', 'datavalue', 'datavaluealt',
#        'stratificationcategory1', 'stratification1', 'locationid', 'topicid',
#        'questionid', 'datavaluetypeid', 'stratificationcategoryid1',
#        'stratificationid1', 'datavalueunit', 'lowconfidencelimit',
#        'highconfidencelimit', 'datavaluefootnotesymbol', 'datavaluefootnote'],
#       dtype='object')

# %%
asthma_df['question'].unique()
# Out:
# array(['Asthma mortality rate',
#        'Emergency department visit rate for asthma',
#        'Hospitalizations for asthma',
#        'Current asthma prevalence among adults aged >= 18 years',
#        'Asthma prevalence among women aged 18-44 years',
#        'Influenza vaccination among noninstitutionalized adults aged 18-64 years with asthma',
#        'Influenza vaccination among noninstitutionalized adults aged >= 65 years with asthma',
#        'Pneumococcal vaccination among noninstitutionalized adults aged 18-64 years with asthma',
#        'Pneumococcal vaccination among noninstitutionalized adults aged >= 65 years with asthma'],
#       dtype=object)

# %%
questions_OI = ['Asthma mortality rate','Emergency department visit rate for asthma','Hospitalizations for asthma',\
               'Current asthma prevalence among adults aged >= 18 years','Asthma prevalence among women aged 18-44 years']

# %%
questionids_list=[]
for question in questions_OI:
    questionids_list += list(asthma_df[asthma_df['question']==question]['questionid'].unique())
print(questionids_list)
# Out:
# ['AST4_1', 'AST2_1', 'AST3_1', 'AST1_1', 'AST1_2']

# %%
# filtering the dataset for the questions of interest
filtered_asthma_df = asthma_df[asthma_df['questionid'].isin(questionids_list)]
filtered_asthma_df
# Out:
#       yearstart yearend locationabbr   locationdesc datasource   topic  \
# 0          2012    2012           AL        Alabama       NVSS  Asthma
# 1          2014    2014           AL        Alabama       NVSS  Asthma
# 2          2011    2011           AZ        Arizona       NVSS  Asthma
# 3          2015    2015           CT    Connecticut       NVSS  Asthma
# 4          2011    2011           FL        Florida       NVSS  Asthma
# ...         ...     ...          ...            ...        ...     ...
# 37547      2019    2019           ID          Idaho      BRFSS  Asthma
# 37548      2017    2017           GA        Georgia      BRFSS  Asthma
# 37549      2013    2013           FL        Florida      BRFSS  Asthma
# 37550      2014    2014           MO       Missouri      BRFSS  Asthma
# 37551      2013    2013           WV  West Virginia      BRFSS  Asthma
#
#                                                 question  \
# 0                                  Asthma mortality rate
# 1                                  Asthma mortality rate
# 2                                  Asthma mortality rate
# 3                                  Asthma mortality rate
# 4                                  Asthma mortality rate
# ...                                                  ...
# 37547  Current asthma prevalence among adults aged >=...
# 37548     Asthma prevalence among women aged 18-44 years
# 37549     Asthma prevalence among women aged 18-44 years
# 37550  Current asthma prevalence among adults aged >=...
# 37551  Current asthma prevalence among adults aged >=...
#
#                  datavaluetype datavalue datavaluealt  ... topicid questionid  \
# 0                       Number        37           37  ...     AST     AST4_1
# 1                       Number        22           22  ...     AST     AST4_1
# 2                       Number        29           29  ...     AST     AST4_1
# 3                       Number        34           34  ...     AST     AST4_1
# 4                       Number        54           54  ...     AST     AST4_1
# ...                        ...       ...          ...  ...     ...        ...
# 37547  Age-adjusted Prevalence       7.9          7.9  ...     AST     AST1_1
# 37548         Crude Prevalence      12.2         12.2  ...     AST     AST1_2
# 37549         Crude Prevalence        10           10  ...     AST     AST1_2
# 37550         Crude Prevalence       9.7          9.7  ...     AST     AST1_1
# 37551         Crude Prevalence         9            9  ...     AST     AST1_1
#
#       datavaluetypeid stratificationcategoryid1 stratificationid1  \
# 0                NMBR                    GENDER              GENF
# 1                NMBR                    GENDER              GENM
# 2                NMBR                    GENDER              GENM
# 3                NMBR                    GENDER              GENF
# 4                NMBR                    GENDER              GENM
# ...               ...                       ...               ...
# 37547      AGEADJPREV                    GENDER              GENM
# 37548         CRDPREV                      RACE               WHT
# 37549         CRDPREV                   OVERALL               OVR
# 37550         CRDPREV                   OVERALL               OVR
# 37551         CRDPREV                   OVERALL               OVR
#
#       datavalueunit lowconfidencelimit highconfidencelimit  \
# 0               NaN                NaN                 NaN
# 1               NaN                NaN                 NaN
# 2               NaN                NaN                 NaN
# 3               NaN                NaN                 NaN
# 4               NaN                NaN                 NaN
# ...             ...                ...                 ...
# 37547             %                6.4                 9.7
# 37548             %                8.8                16.8
# 37549             %                8.6                11.5
# 37550             %                8.7                10.8
# 37551             %                8.2                 9.9
#
#       datavaluefootnotesymbol datavaluefootnote
# 0                         NaN               NaN
# 1                         NaN               NaN
# 2                         NaN               NaN
# 3                         NaN               NaN
# 4                         NaN               NaN
# ...                       ...               ...
# 37547                     NaN               NaN
# 37548                     NaN               NaN
# 37549                     NaN               NaN
# 37550                     NaN               NaN
# 37551                     NaN               NaN
#
# [33400 rows x 23 columns]

# %%
#checking if column 'yearstart' and 'yearend' are the same
print(f"Are the columns datavalue and datavaluealt end the same?\n{filtered_asthma_df['datavalue'].equals(filtered_asthma_df['datavaluealt'])}")
print(f"Are the columns yearstart and year end the same?\n{filtered_asthma_df['yearstart'].equals(filtered_asthma_df['yearend'])}")
#if these columns are the same drop one of the duplicates and other not useful columns
if filtered_asthma_df['yearstart'].equals(filtered_asthma_df['yearend']):
    columns_to_drop = ['yearend',\
                        'topic',\
                        'datavaluealt',\
                        'topicid',\
                        'datavaluetypeid',\
                        'stratificationcategoryid1',\
                        'stratificationid1',\
                        'lowconfidencelimit',\
                       'highconfidencelimit',\
                       'datavaluefootnotesymbol',\
                      'datavaluefootnote']
    filtered_asthma_df=filtered_asthma_df.drop(columns=columns_to_drop)
    print(f"The following columns {columns_to_drop} were dropped")
# Out:
# Are the columns datavalue and datavaluealt end the same?
# True
# Are the columns yearstart and year end the same?
# True
# The following columns ['yearend', 'topic', 'datavaluealt', 'topicid', 'datavaluetypeid', 'stratificationcategoryid1', 'stratificationid1', 'lowconfidencelimit', 'highconfidencelimit', 'datavaluefootnotesymbol', 'datavaluefootnote'] were dropped

# %%
filtered_asthma_df=filtered_asthma_df.rename(columns={"yearstart": "year","locationabbr":"state_id","locationdesc":"state"})

# %%
#checking for missing data
filtered_asthma_df.isnull().sum()
# Out:
# year                           0
# state_id                       0
# state                          0
# datasource                     0
# question                       0
# datavaluetype                  0
# datavalue                  17259
# stratificationcategory1        0
# stratification1                0
# locationid                     0
# questionid                     0
# datavalueunit               7548
# dtype: int64

# %%
# removing missing data values
filtered_asthma_df=filtered_asthma_df[filtered_asthma_df['datavalue'].isna()==False]
filtered_asthma_df
# Out:
#        year state_id          state datasource  \
# 0      2012       AL        Alabama       NVSS
# 1      2014       AL        Alabama       NVSS
# 2      2011       AZ        Arizona       NVSS
# 3      2015       CT    Connecticut       NVSS
# 4      2011       FL        Florida       NVSS
# ...     ...      ...            ...        ...
# 37547  2019       ID          Idaho      BRFSS
# 37548  2017       GA        Georgia      BRFSS
# 37549  2013       FL        Florida      BRFSS
# 37550  2014       MO       Missouri      BRFSS
# 37551  2013       WV  West Virginia      BRFSS
#
#                                                 question  \
# 0                                  Asthma mortality rate
# 1                                  Asthma mortality rate
# 2                                  Asthma mortality rate
# 3                                  Asthma mortality rate
# 4                                  Asthma mortality rate
# ...                                                  ...
# 37547  Current asthma prevalence among adults aged >=...
# 37548     Asthma prevalence among women aged 18-44 years
# 37549     Asthma prevalence among women aged 18-44 years
# 37550  Current asthma prevalence among adults aged >=...
# 37551  Current asthma prevalence among adults aged >=...
#
#                  datavaluetype datavalue stratificationcategory1  \
# 0                       Number        37                  Gender
# 1                       Number        22                  Gender
# 2                       Number        29                  Gender
# 3                       Number        34                  Gender
# 4                       Number        54                  Gender
# ...                        ...       ...                     ...
# 37547  Age-adjusted Prevalence       7.9                  Gender
# 37548         Crude Prevalence      12.2          Race/Ethnicity
# 37549         Crude Prevalence        10                 Overall
# 37550         Crude Prevalence       9.7                 Overall
# 37551         Crude Prevalence         9                 Overall
#
#            stratification1 locationid questionid datavalueunit
# 0                   Female          1     AST4_1           NaN
# 1                     Male          1     AST4_1           NaN
# 2                     Male          4     AST4_1           NaN
# 3                   Female          9     AST4_1           NaN
# 4                     Male         12     AST4_1           NaN
# ...                    ...        ...        ...           ...
# 37547                 Male         16     AST1_1             %
# 37548  White, non-Hispanic         13     AST1_2             %
# 37549              Overall         12     AST1_2             %
# 37550              Overall         29     AST1_1             %
# 37551              Overall         54     AST1_1             %
#
# [16141 rows x 12 columns]

# %%
# checking that all the missing data value were correctly removed
filtered_asthma_df.isnull().sum()
# Out:
# year                          0
# state_id                      0
# state                         0
# datasource                    0
# question                      0
# datavaluetype                 0
# datavalue                     0
# stratificationcategory1       0
# stratification1               0
# locationid                    0
# questionid                    0
# datavalueunit              2827
# dtype: int64

# %%
filtered_asthma_df['question'].unique()
# Out:
# array(['Asthma mortality rate',
#        'Emergency department visit rate for asthma',
#        'Hospitalizations for asthma',
#        'Current asthma prevalence among adults aged >= 18 years',
#        'Asthma prevalence among women aged 18-44 years'], dtype=object)

# %%
# drop territories (PR, GU, VI) and nation-wide data (US)
state_to_drop = ['PR','GU','US','VI']
filtered_asthma_df = filtered_asthma_df[~filtered_asthma_df['state_id'].isin(state_to_drop)]

filtered_asthma_df
# Out:
#        year state_id          state datasource  \
# 0      2012       AL        Alabama       NVSS
# 1      2014       AL        Alabama       NVSS
# 2      2011       AZ        Arizona       NVSS
# 3      2015       CT    Connecticut       NVSS
# 4      2011       FL        Florida       NVSS
# ...     ...      ...            ...        ...
# 37547  2019       ID          Idaho      BRFSS
# 37548  2017       GA        Georgia      BRFSS
# 37549  2013       FL        Florida      BRFSS
# 37550  2014       MO       Missouri      BRFSS
# 37551  2013       WV  West Virginia      BRFSS
#
#                                                 question  \
# 0                                  Asthma mortality rate
# 1                                  Asthma mortality rate
# 2                                  Asthma mortality rate
# 3                                  Asthma mortality rate
# 4                                  Asthma mortality rate
# ...                                                  ...
# 37547  Current asthma prevalence among adults aged >=...
# 37548     Asthma prevalence among women aged 18-44 years
# 37549     Asthma prevalence among women aged 18-44 years
# 37550  Current asthma prevalence among adults aged >=...
# 37551  Current asthma prevalence among adults aged >=...
#
#                  datavaluetype datavalue stratificationcategory1  \
# 0                       Number        37                  Gender
# 1                       Number        22                  Gender
# 2                       Number        29                  Gender
# 3                       Number        34                  Gender
# 4                       Number        54                  Gender
# ...                        ...       ...                     ...
# 37547  Age-adjusted Prevalence       7.9                  Gender
# 37548         Crude Prevalence      12.2          Race/Ethnicity
# 37549         Crude Prevalence        10                 Overall
# 37550         Crude Prevalence       9.7                 Overall
# 37551         Crude Prevalence         9                 Overall
#
#            stratification1 locationid questionid datavalueunit
# 0                   Female          1     AST4_1           NaN
# 1                     Male          1     AST4_1           NaN
# 2                     Male          4     AST4_1           NaN
# 3                   Female          9     AST4_1           NaN
# 4                     Male         12     AST4_1           NaN
# ...                    ...        ...        ...           ...
# 37547                 Male         16     AST1_1             %
# 37548  White, non-Hispanic         13     AST1_2             %
# 37549              Overall         12     AST1_2             %
# 37550              Overall         29     AST1_1             %
# 37551              Overall         54     AST1_1             %
#
# [15860 rows x 12 columns]

# %%
#checking for duplicates
filtered_asthma_df=filtered_asthma_df.drop_duplicates()
filtered_asthma_df
# Out:
#        year state_id          state datasource  \
# 0      2012       AL        Alabama       NVSS
# 1      2014       AL        Alabama       NVSS
# 2      2011       AZ        Arizona       NVSS
# 3      2015       CT    Connecticut       NVSS
# 4      2011       FL        Florida       NVSS
# ...     ...      ...            ...        ...
# 37547  2019       ID          Idaho      BRFSS
# 37548  2017       GA        Georgia      BRFSS
# 37549  2013       FL        Florida      BRFSS
# 37550  2014       MO       Missouri      BRFSS
# 37551  2013       WV  West Virginia      BRFSS
#
#                                                 question  \
# 0                                  Asthma mortality rate
# 1                                  Asthma mortality rate
# 2                                  Asthma mortality rate
# 3                                  Asthma mortality rate
# 4                                  Asthma mortality rate
# ...                                                  ...
# 37547  Current asthma prevalence among adults aged >=...
# 37548     Asthma prevalence among women aged 18-44 years
# 37549     Asthma prevalence among women aged 18-44 years
# 37550  Current asthma prevalence among adults aged >=...
# 37551  Current asthma prevalence among adults aged >=...
#
#                  datavaluetype datavalue stratificationcategory1  \
# 0                       Number        37                  Gender
# 1                       Number        22                  Gender
# 2                       Number        29                  Gender
# 3                       Number        34                  Gender
# 4                       Number        54                  Gender
# ...                        ...       ...                     ...
# 37547  Age-adjusted Prevalence       7.9                  Gender
# 37548         Crude Prevalence      12.2          Race/Ethnicity
# 37549         Crude Prevalence        10                 Overall
# 37550         Crude Prevalence       9.7                 Overall
# 37551         Crude Prevalence         9                 Overall
#
#            stratification1 locationid questionid datavalueunit
# 0                   Female          1     AST4_1           NaN
# 1                     Male          1     AST4_1           NaN
# 2                     Male          4     AST4_1           NaN
# 3                   Female          9     AST4_1           NaN
# 4                     Male         12     AST4_1           NaN
# ...                    ...        ...        ...           ...
# 37547                 Male         16     AST1_1             %
# 37548  White, non-Hispanic         13     AST1_2             %
# 37549              Overall         12     AST1_2             %
# 37550              Overall         29     AST1_1             %
# 37551              Overall         54     AST1_1             %
#
# [15844 rows x 12 columns]

# %%
#checking that there isn't more than one data value entry for the same year and state.
duplicateRowsDF = filtered_asthma_df[filtered_asthma_df.duplicated(subset=['year','state_id','state','datasource','question','datavaluetype','datavaluetype','stratificationcategory1','stratification1','locationid','questionid','datavalueunit'], keep=False)]
duplicateRowsDF
# Out:
# Empty DataFrame
# Columns: [year, state_id, state, datasource, question, datavaluetype, datavalue, stratificationcategory1, stratification1, locationid, questionid, datavalueunit]
# Index: []

# %%
#keeping only the Overall values
filtered_asthma_df = filtered_asthma_df[filtered_asthma_df['stratificationcategory1'] == 'Overall']
filtered_asthma_df
# Out:
#        year state_id           state datasource  \
# 6      2011       HI          Hawaii       NVSS
# 7      2013       HI          Hawaii       NVSS
# 12     2012       TX           Texas       NVSS
# 14     2015       WA      Washington       NVSS
# 21     2019       NY        New York      BRFSS
# ...     ...      ...             ...        ...
# 37524  2013       ID           Idaho      BRFSS
# 37536  2019       NC  North Carolina      BRFSS
# 37549  2013       FL         Florida      BRFSS
# 37550  2014       MO        Missouri      BRFSS
# 37551  2013       WV   West Virginia      BRFSS
#
#                                                 question  \
# 6                                  Asthma mortality rate
# 7                                  Asthma mortality rate
# 12                                 Asthma mortality rate
# 14                                 Asthma mortality rate
# 21        Asthma prevalence among women aged 18-44 years
# ...                                                  ...
# 37524  Current asthma prevalence among adults aged >=...
# 37536  Current asthma prevalence among adults aged >=...
# 37549     Asthma prevalence among women aged 18-44 years
# 37550  Current asthma prevalence among adults aged >=...
# 37551  Current asthma prevalence among adults aged >=...
#
#                  datavaluetype datavalue stratificationcategory1  \
# 6                       Number        26                 Overall
# 7                       Number        24                 Overall
# 12                      Number       206                 Overall
# 14                      Number        88                 Overall
# 21            Crude Prevalence        12                 Overall
# ...                        ...       ...                     ...
# 37524  Age-adjusted Prevalence       8.7                 Overall
# 37536  Age-adjusted Prevalence       8.2                 Overall
# 37549         Crude Prevalence        10                 Overall
# 37550         Crude Prevalence       9.7                 Overall
# 37551         Crude Prevalence         9                 Overall
#
#       stratification1 locationid questionid datavalueunit
# 6             Overall         15     AST4_1           NaN
# 7             Overall         15     AST4_1           NaN
# 12            Overall         48     AST4_1           NaN
# 14            Overall         53     AST4_1           NaN
# 21            Overall         36     AST1_2             %
# ...               ...        ...        ...           ...
# 37524         Overall         16     AST1_1             %
# 37536         Overall         37     AST1_1             %
# 37549         Overall         12     AST1_2             %
# 37550         Overall         29     AST1_1             %
# 37551         Overall         54     AST1_1             %
#
# [3034 rows x 12 columns]

# %%
# final dropping of unnecessary columns
filtered_asthma_df=filtered_asthma_df.drop(columns=['state',\
                                                    'datasource',\
                                                    'question',\
                                                    'stratificationcategory1',\
                                                    'stratification1',\
                                                    'locationid',\
                                                    'questionid'])
filtered_asthma_df
# Out:
#        year state_id            datavaluetype datavalue datavalueunit
# 6      2011       HI                   Number        26           NaN
# 7      2013       HI                   Number        24           NaN
# 12     2012       TX                   Number       206           NaN
# 14     2015       WA                   Number        88           NaN
# 21     2019       NY         Crude Prevalence        12             %
# ...     ...      ...                      ...       ...           ...
# 37524  2013       ID  Age-adjusted Prevalence       8.7             %
# 37536  2019       NC  Age-adjusted Prevalence       8.2             %
# 37549  2013       FL         Crude Prevalence        10             %
# 37550  2014       MO         Crude Prevalence       9.7             %
# 37551  2013       WV         Crude Prevalence         9             %
#
# [3034 rows x 5 columns]

# %%
# adding the asthma table to the database and controlling that there are data recorded.
add_table_to_db('asthma',filtered_asthma_df, conn)
# Out:
# [(6, '2011', 'HI', 'Number', '26', None),
#  (7, '2013', 'HI', 'Number', '24', None),
#  (12, '2012', 'TX', 'Number', '206', None),
#  (14, '2015', 'WA', 'Number', '88', None),
#  (21, '2019', 'NY', 'Crude Prevalence', '12', '%'),
#  (22, '2011', 'VA', 'Crude Prevalence', '11.9', '%'),
#  (24, '2014', 'GA', 'Number', '96', None),
#  (31, '2013', 'IN', 'Number', '69', None),
#  (34, '2012', 'CA', 'Number', '384', None),
#  (41, '2013', 'NC', 'Number', '112', None),
#  (42, '2013', 'WA', 'Number', '87', None),
#  (45, '2016', 'NY', 'Number', '273', None),
#  (58, '2017', 'IA', 'Number', '32', None),
#  (69, '2017', 'AR', 'Crude Rate', '10.7', 'cases per 1,000,000'),
#  (74, '2013', 'AL', 'Crude Rate', '8.7', 'cases per 1,000,000'),
#  (81, '2015', 'CT', 'Crude Rate', '13.4', 'cases per 1,000,000'),
#  (83, '2011', 'CO', 'Crude Rate', '8.2', 'cases per 1,000,000'),
#  (84, '2014', 'IL', 'Age-adjusted Rate', '12.2', 'cases per 1,000,000'),
#  (85, '2015', 'IA', 'Crude Rate', '13.1', 'cases per 1,000,000'),
#  (92, '2013', 'CT', 'Number', '36', None),
#  (100, '2017', 'ID', 'Crude Rate', '15.7', 'cases per 1,000,000'),
#  (107, '2011', 'FL', 'Number', '148', None),
#  (111, '2012', 'KS', 'Age-adjusted Rate', '8.9', 'cases per 1,000,000'),
#  (156, '2010', 'KS', 'Crude Rate', '11.6', 'cases per 1,000,000'),
#  (182, '2014', 'CO', 'Number', '41', None),
#  (185, '2014', 'HI', 'Age-adjusted Rate', '14.6', 'cases per 1,000,000'),
#  (195, '2012', 'CA', 'Crude Rate', '10.1', 'cases per 1,000,000'),
#  (200, '2014', 'CA', 'Number', '407', None),
#  (208, '2015', 'AL', 'Number', '52', None),
#  (209, '2011', 'IL', 'Age-adjusted Rate', '13.3', 'cases per 1,000,000'),
#  (233, '2014', 'FL', 'Age-adjusted Rate', '8.6', 'cases per 1,000,000'),
#  (242, '2012', 'IA', 'Crude Rate', '11.4', 'cases per 1,000,000'),
#  (249, '2012', 'IN', 'Age-adjusted Rate', '10.3', 'cases per 1,000,000'),
#  (251, '2013', 'GA', 'Age-adjusted Rate', '10.2', 'cases per 1,000,000'),
#  (259, '2016', 'ID', 'Number', '21', None),
#  (260, '2017', 'AZ', 'Number', '92', None),
#  (263, '2017', 'GA', 'Crude Rate', '10.4', 'cases per 1,000,000'),
#  (269, '2010', 'CA', 'Number', '403', None),
#  (273, '2013', 'HI', 'Crude Rate', '17.1', 'cases per 1,000,000'),
#  (311, '2010', 'IA', 'Number', '46', None),
#  (314, '2011', 'IN', 'Crude Rate', '11.2', 'cases per 1,000,000'),
#  (316, '2017', 'IL', 'Number', '149', None),
#  (320, '2015', 'AZ', 'Age-adjusted Rate', '10', 'cases per 1,000,000'),
#  (330, '2015', 'AR', 'Number', '30', None),
#  (331, '2015', 'IL', 'Crude Rate', '12.2', 'cases per 1,000,000'),
#  (335, '2014', 'ID', 'Crude Rate', '13.5', 'cases per 1,000,000'),
#  (336, '2015', 'AR', 'Age-adjusted Rate', '9.8', 'cases per 1,000,000'),
#  (346, '2015', 'KS', 'Number', '29', None),
#  (348, '2017', 'AL', 'Age-adjusted Rate', '13.7', 'cases per 1,000,000'),
#  (349, '2016', 'GA', 'Number', '93', None),
#  (363, '2011', 'KS', 'Crude Rate', '8.7', 'cases per 1,000,000'),
#  (392, '2011', 'CA', 'Age-adjusted Rate', '10.7', 'cases per 1,000,000'),
#  (399, '2014', 'IN', 'Crude Rate', '11.1', 'cases per 1,000,000'),
#  (412, '2012', 'ID', 'Age-adjusted Rate', '13.2', 'cases per 1,000,000'),
#  (420, '2010', 'CO', 'Crude Rate', '9.5', 'cases per 1,000,000'),
#  (423, '2011', 'HI', 'Age-adjusted Rate', '16', 'cases per 1,000,000'),
#  (426, '2010', 'CT', 'Number', '45', None),
#  (457, '2013', 'IN', 'Crude Rate', '10.5', 'cases per 1,000,000'),
#  (469, '2013', 'CA', 'Crude Rate', '10.7', 'cases per 1,000,000'),
#  (484, '2013', 'ID', 'Age-adjusted Rate', '13.3', 'cases per 1,000,000'),
#  (490, '2015', 'IL', 'Age-adjusted Rate', '11.6', 'cases per 1,000,000'),
#  (500, '2014', 'AR', 'Number', '33', None),
#  (516, '2010', 'ID', 'Crude Rate', '13.4', 'cases per 1,000,000'),
#  (518, '2012', 'CT', 'Number', '39', None),
#  (534, '2010', 'AL', 'Age-adjusted Rate', '11.9', 'cases per 1,000,000'),
#  (535, '2010', 'AR', 'Age-adjusted Rate', '11.4', 'cases per 1,000,000'),
#  (539, '2014', 'IA', 'Crude Rate', '17.4', 'cases per 1,000,000'),
#  (550, '2016', 'IN', 'Crude Rate', '8.3', 'cases per 1,000,000'),
#  (555, '2013', 'AR', 'Number', '36', None),
#  (556, '2016', 'IA', 'Age-adjusted Rate', '9.3', 'cases per 1,000,000'),
#  (583, '2015', 'CA', 'Number', '393', None),
#  (595, '2014', 'KS', 'Crude Rate', '9.3', 'cases per 1,000,000'),
#  (609, '2011', 'AL', 'Number', '36', None),
#  (620, '2010', 'IL', 'Age-adjusted Rate', '13.9', 'cases per 1,000,000'),
#  (649, '2016', 'CT', 'Number', '44', None),
#  (653, '2013', 'AZ', 'Number', '98', None),
#  (659, '2014', 'CO', 'Crude Rate', '7.7', 'cases per 1,000,000'),
#  (662, '2010', 'IN', 'Age-adjusted Rate', '10.5', 'cases per 1,000,000'),
#  (666, '2010', 'GA', 'Number', '97', None),
#  (672, '2015', 'IN', 'Age-adjusted Rate', '12.9', 'cases per 1,000,000'),
#  (678, '2016', 'AR', 'Crude Rate', '15.1', 'cases per 1,000,000'),
#  (683, '2017', 'IN', 'Crude Rate', '11.7', 'cases per 1,000,000'),
#  (685, '2017', 'HI', 'Age-adjusted Rate', '13.4', 'cases per 1,000,000'),
#  (687, '2012', 'CO', 'Age-adjusted Rate', '10.6', 'cases per 1,000,000'),
#  (700, '2011', 'KS', 'Number', '25', None),
#  (711, '2015', 'FL', 'Number', '175', None),
#  (720, '2014', 'AZ', 'Age-adjusted Rate', '11.7', 'cases per 1,000,000'),
#  (739, '2012', 'GA', 'Number', '93', None),
#  (766, '2013', 'IL', 'Number', '192', None),
#  (771, '2015', 'CA', 'Age-adjusted Rate', '9.5', 'cases per 1,000,000'),
#  (776, '2011', 'GA', 'Age-adjusted Rate', '10.5', 'cases per 1,000,000'),
#  (784, '2013', 'GA', 'Crude Rate', '10.1', 'cases per 1,000,000'),
#  (799, '2016', 'CO', 'Age-adjusted Rate', '8.3', 'cases per 1,000,000'),
#  (821, '2011', 'IA', 'Age-adjusted Rate', '12.5', 'cases per 1,000,000'),
#  (870, '2014', 'AZ', 'Crude Rate', '12.8', 'cases per 1,000,000'),
#  (876, '2014', 'ID', 'Age-adjusted Rate', '13', 'cases per 1,000,000'),
#  (883, '2017', 'AL', 'Crude Rate', '15.2', 'cases per 1,000,000'),
#  (889, '2012', 'IA', 'Age-adjusted Rate', '9.8', 'cases per 1,000,000'),
#  (893, '2011', 'AR', 'Age-adjusted Rate', '14.2', 'cases per 1,000,000'),
#  (894, '2011', 'AR', 'Number', '46', None),
#  (919, '2012', 'CA', 'Age-adjusted Rate', '9.8', 'cases per 1,000,000'),
#  (928, '2012', 'CO', 'Crude Rate', '10.6', 'cases per 1,000,000'),
#  (929, '2013', 'AL', 'Age-adjusted Rate', '8.4', 'cases per 1,000,000'),
#  (931, '2017', 'HI', 'Crude Rate', '16.8', 'cases per 1,000,000'),
#  (941, '2010', 'CO', 'Number', '48', None),
#  (950, '2017', 'CO', 'Number', '46', None),
#  (951, '2017', 'IL', 'Crude Rate', '11.6', 'cases per 1,000,000'),
#  (963, '2016', 'AL', 'Age-adjusted Rate', '9.1', 'cases per 1,000,000'),
#  (964, '2015', 'KS', 'Crude Rate', '10', 'cases per 1,000,000'),
#  (988, '2010', 'CA', 'Crude Rate', '10.8', 'cases per 1,000,000'),
#  (1002, '2017', 'AZ', 'Crude Rate', '13.1', 'cases per 1,000,000'),
#  (1027, '2015', 'CO', 'Crude Rate', '8.4', 'cases per 1,000,000'),
#  (1029, '2011', 'CO', 'Age-adjusted Rate', '8.4', 'cases per 1,000,000'),
#  (1030, '2013', 'KS', 'Number', '32', None),
#  (1045, '2010', 'IA', 'Crude Rate', '15.1', 'cases per 1,000,000'),
#  (1055, '2017', 'ID', 'Age-adjusted Rate', '13.8', 'cases per 1,000,000'),
#  (1062, '2011', 'IN', 'Age-adjusted Rate', '10.4', 'cases per 1,000,000'),
#  (1066, '2013', 'FL', 'Age-adjusted Rate', '8.4', 'cases per 1,000,000'),
#  (1068, '2014', 'CA', 'Crude Rate', '10.5', 'cases per 1,000,000'),
#  (1078, '2011', 'GA', 'Number', '96', None),
#  (1103, '2016', 'FL', 'Number', '184', None),
#  (1107, '2010', 'KS', 'Number', '33', None),
#  (1109, '2010', 'GA', 'Crude Rate', '10', 'cases per 1,000,000'),
#  (1115, '2012', 'AZ', 'Age-adjusted Rate', '11.6', 'cases per 1,000,000'),
#  (1131, '2015', 'IA', 'Age-adjusted Rate', '10.7', 'cases per 1,000,000'),
#  (1178, '2015', 'AL', 'Crude Rate', '10.7', 'cases per 1,000,000'),
#  (1201, '2016', 'ID', 'Crude Rate', '12.5', 'cases per 1,000,000'),
#  (1206, '2011', 'KS', 'Age-adjusted Rate', '8', 'cases per 1,000,000'),
#  (1221, '2017', 'GA', 'Age-adjusted Rate', '10.1', 'cases per 1,000,000'),
#  (1222, '2010', 'FL', 'Number', '177', None),
#  (1229, '2017', 'AR', 'Number', '32', None),
#  (1231, '2017', 'IA', 'Crude Rate', '10.2', 'cases per 1,000,000'),
#  (1236, '2013', 'HI', 'Age-adjusted Rate', '13.6', 'cases per 1,000,000'),
#  (1246, '2014', 'IN', 'Age-adjusted Rate', '10.3', 'cases per 1,000,000'),
#  (1248, '2016', 'AZ', 'Age-adjusted Rate', '14.2', 'cases per 1,000,000'),
#  (1276, '2010', 'IL', 'Crude Rate', '14.3', 'cases per 1,000,000'),
#  (1282, '2015', 'ID', 'Age-adjusted Rate', '11.6', 'cases per 1,000,000'),
#  (1285, '2016', 'IN', 'Age-adjusted Rate', '7.8', 'cases per 1,000,000'),
#  (1305, '2017', 'FL', 'Age-adjusted Rate', '7', 'cases per 1,000,000'),
#  (1331, '2017', 'CA', 'Number', '399', None),
#  (1335, '2013', 'AR', 'Crude Rate', '12.2', 'cases per 1,000,000'),
#  (1339, '2010', 'AZ', 'Number', '58', None),
#  (1352, '2017', 'IN', 'Number', '78', None),
#  (1376, '2010', 'AL', 'Crude Rate', '12.8', 'cases per 1,000,000'),
#  (1391, '2010', 'AR', 'Crude Rate', '12.7', 'cases per 1,000,000'),
#  (1393, '2013', 'IA', 'Age-adjusted Rate', '10', 'cases per 1,000,000'),
#  (1405, '2011', 'IA', 'Crude Rate', '14', 'cases per 1,000,000'),
#  (1411, '2016', 'IA', 'Crude Rate', '10.8', 'cases per 1,000,000'),
#  (1426, '2011', 'CT', 'Crude Rate', '6.7', 'cases per 1,000,000'),
#  (1428, '2010', 'ID', 'Age-adjusted Rate', '13.5', 'cases per 1,000,000'),
#  (1439, '2013', 'CO', 'Number', '51', None),
#  (1449, '2016', 'AZ', 'Crude Rate', '15.6', 'cases per 1,000,000'),
#  (1451, '2013', 'ID', 'Crude Rate', '14.3', 'cases per 1,000,000'),
#  (1463, '2014', 'KS', 'Number', '27', None),
#  (1472, '2013', 'IL', 'Crude Rate', '14.9', 'cases per 1,000,000'),
#  (1488, '2016', 'CO', 'Crude Rate', '8.3', 'cases per 1,000,000'),
#  (1504, '2012', 'KS', 'Crude Rate', '9', 'cases per 1,000,000'),
#  (1505, '2012', 'IL', 'Age-adjusted Rate', '12.7', 'cases per 1,000,000'),
#  (1517, '2014', 'IA', 'Number', '54', None),
#  (1522, '2016', 'CT', 'Crude Rate', '12.3', 'cases per 1,000,000'),
#  (1541, '2015', 'AZ', 'Number', '76', None),
#  (1543, '2011', 'AL', 'Crude Rate', '7.5', 'cases per 1,000,000'),
#  (1550, '2016', 'AR', 'Age-adjusted Rate', '14.3', 'cases per 1,000,000'),
#  (1557, '2011', 'GA', 'Crude Rate', '9.8', 'cases per 1,000,000'),
#  (1564, '2014', 'IL', 'Crude Rate', '13', 'cases per 1,000,000'),
#  (1565, '2014', 'CT', 'Number', '36', None),
#  (1566, '2014', 'GA', 'Age-adjusted Rate', '9.9', 'cases per 1,000,000'),
#  (1603, '2013', 'AZ', 'Crude Rate', '14.8', 'cases per 1,000,000'),
#  (1604, '2012', 'AR', 'Age-adjusted Rate', '9.8', 'cases per 1,000,000'),
#  (1607, '2016', 'CA', 'Number', '391', None),
#  (1617, '2016', 'IL', 'Age-adjusted Rate', '10.5', 'cases per 1,000,000'),
#  (1623, '2012', 'FL', 'Number', '195', None),
#  (1632, '2010', 'IN', 'Crude Rate', '10.6', 'cases per 1,000,000'),
#  (1639, '2013', 'CA', 'Number', '410', None),
#  (1648, '2015', 'IN', 'Crude Rate', '13.6', 'cases per 1,000,000'),
#  (1665, '2014', 'AR', 'Crude Rate', '11.1', 'cases per 1,000,000'),
#  (1666, '2012', 'CT', 'Crude Rate', '10.9', 'cases per 1,000,000'),
#  (1667, '2014', 'AL', 'Age-adjusted Rate', '10.7', 'cases per 1,000,000'),
#  (1672, '2011', 'AZ', 'Number', '92', None),
#  (1683, '2011', 'AL', 'Age-adjusted Rate', '7.4', 'cases per 1,000,000'),
#  (1690, '2010', 'FL', 'Crude Rate', '9.4', 'cases per 1,000,000'),
#  (1698, '2012', 'ID', 'Number', '21', None),
#  (1703, '2014', 'GA', 'Crude Rate', '9.5', 'cases per 1,000,000'),
#  (1711, '2016', 'GA', 'Age-adjusted Rate', '9.2', 'cases per 1,000,000'),
#  (1722, '2010', 'IL', 'Number', '183', None),
#  (1726, '2010', 'CT', 'Age-adjusted Rate', '10.4', 'cases per 1,000,000'),
#  (1739, '2014', 'CA', 'Age-adjusted Rate', '10', 'cases per 1,000,000'),
#  (1779, '2017', 'AZ', 'Age-adjusted Rate', '11.7', 'cases per 1,000,000'),
#  (1808, '2015', 'CO', 'Age-adjusted Rate', '8.5', 'cases per 1,000,000'),
#  (1826, '2017', 'IL', 'Age-adjusted Rate', '10.9', 'cases per 1,000,000'),
#  (1844, '2015', 'KS', 'Age-adjusted Rate', '9.6', 'cases per 1,000,000'),
#  (1855, '2011', 'AZ', 'Age-adjusted Rate', '13.3', 'cases per 1,000,000'),
#  (1886, '2016', 'FL', 'Crude Rate', '8.9', 'cases per 1,000,000'),
#  (1900, '2014', 'FL', 'Number', '191', None),
#  (1923, '2014', 'HI', 'Number', '24', None),
#  (1925, '2012', 'FL', 'Age-adjusted Rate', '8.7', 'cases per 1,000,000'),
#  (1934, '2017', 'CO', 'Crude Rate', '8.2', 'cases per 1,000,000'),
#  (1941, '2013', 'KS', 'Crude Rate', '11.1', 'cases per 1,000,000'),
#  (1948, '2015', 'AL', 'Age-adjusted Rate', '9.8', 'cases per 1,000,000'),
#  (1960, '2012', 'IN', 'Number', '72', None),
#  (1961, '2011', 'CA', 'Crude Rate', '10.7', 'cases per 1,000,000'),
#  (1973, '2016', 'ID', 'Age-adjusted Rate', '11.3', 'cases per 1,000,000'),
#  (1978, '2011', 'AR', 'Crude Rate', '15.7', 'cases per 1,000,000'),
#  (1987, '2010', 'GA', 'Age-adjusted Rate', '10.8', 'cases per 1,000,000'),
#  (1989, '2015', 'GA', 'Crude Rate', '9', 'cases per 1,000,000'),
#  (1990, '2017', 'IA', 'Age-adjusted Rate', '8.8', 'cases per 1,000,000'),
#  (1992, '2015', 'CO', 'Number', '46', None),
#  (1996, '2015', 'IN', 'Number', '90', None),
#  (1997, '2012', 'CO', 'Number', '55', None),
#  (2001, '2012', 'AZ', 'Crude Rate', '12.2', 'cases per 1,000,000'),
#  (2015, '2017', 'HI', 'Number', '24', None),
#  (2032, '2010', 'IA', 'Age-adjusted Rate', '13.8', 'cases per 1,000,000'),
#  (2047, '2014', 'AZ', 'Number', '86', None),
#  (2048, '2013', 'FL', 'Crude Rate', '9.6', 'cases per 1,000,000'),
#  (2052, '2016', 'AL', 'Crude Rate', '9.9', 'cases per 1,000,000'),
#  (2059, '2017', 'AL', 'Number', '74', None),
#  (2083, '2011', 'CT', 'Age-adjusted Rate', '6.1', 'cases per 1,000,000'),
#  (2094, '2010', 'AZ', 'Crude Rate', '9.1', 'cases per 1,000,000'),
#  (2115, '2013', 'IL', 'Age-adjusted Rate', '14', 'cases per 1,000,000'),
#  (2117, '2012', 'AL', 'Age-adjusted Rate', '10.9', 'cases per 1,000,000'),
#  (2119, '2014', 'CT', 'Crude Rate', '10', 'cases per 1,000,000'),
#  (2148, '2012', 'FL', 'Crude Rate', '10.1', 'cases per 1,000,000'),
#  (2151, '2016', 'CA', 'Crude Rate', '10', 'cases per 1,000,000'),
#  (2165, '2017', 'CT', 'Age-adjusted Rate', '9', 'cases per 1,000,000'),
#  (2184, '2015', 'AZ', 'Crude Rate', '11.1', 'cases per 1,000,000'),
#  (2187, '2010', 'IN', 'Number', '69', None),
#  (2191, '2013', 'AR', 'Age-adjusted Rate', '10.9', 'cases per 1,000,000'),
#  (2214, '2014', 'IL', 'Number', '167', None),
#  (2227, '2013', 'CT', 'Age-adjusted Rate', '8.3', 'cases per 1,000,000'),
#  (2231, '2015', 'FL', 'Age-adjusted Rate', '7.4', 'cases per 1,000,000'),
#  (2240, '2011', 'FL', 'Age-adjusted Rate', '6.7', 'cases per 1,000,000'),
#  (2249, '2012', 'KS', 'Number', '26', None),
#  (2259, '2012', 'GA', 'Age-adjusted Rate', '9.5', 'cases per 1,000,000'),
#  (2264, '2016', 'IL', 'Crude Rate', '11.6', 'cases per 1,000,000'),
#  (2292, '2013', 'CO', 'Crude Rate', '9.7', 'cases per 1,000,000'),
#  (2302, '2016', 'AZ', 'Number', '108', None),
#  (2328, '2016', 'CO', 'Number', '46', None),
#  (2339, '2015', 'ID', 'Crude Rate', '12.7', 'cases per 1,000,000'),
#  (2351, '2013', 'AZ', 'Age-adjusted Rate', '13.7', 'cases per 1,000,000'),
#  (2355, '2012', 'AR', 'Crude Rate', '10.2', 'cases per 1,000,000'),
#  (2360, '2016', 'CT', 'Age-adjusted Rate', '11.1', 'cases per 1,000,000'),
#  (2362, '2017', 'FL', 'Crude Rate', '8.5', 'cases per 1,000,000'),
#  (2367, '2011', 'IA', 'Number', '43', None),
#  (2380, '2013', 'ID', 'Number', '23', None),
#  (2386, '2017', 'CA', 'Crude Rate', '10.1', 'cases per 1,000,000'),
#  (2409, '2014', 'AR', 'Age-adjusted Rate', '11', 'cases per 1,000,000'),
#  (2414, '2012', 'CT', 'Age-adjusted Rate', '9.4', 'cases per 1,000,000'),
#  (2417, '2014', 'AL', 'Crude Rate', '11.8', 'cases per 1,000,000'),
#  (2421, '2011', 'AZ', 'Crude Rate', '14.2', 'cases per 1,000,000'),
#  (2436, '2010', 'AL', 'Number', '61', None),
#  (2442, '2015', 'GA', 'Number', '92', None),
#  (2444, '2010', 'AR', 'Number', '37', None),
#  (2447, '2012', 'IL', 'Crude Rate', '13.5', 'cases per 1,000,000'),
#  (2449, '2013', 'IA', 'Crude Rate', '11.6', 'cases per 1,000,000'),
#  (2460, '2011', 'CO', 'Number', '42', None),
#  (2472, '2016', 'IA', 'Number', '34', None),
#  (2474, '2010', 'CA', 'Age-adjusted Rate', '11', 'cases per 1,000,000'),
#  (2485, '2017', 'CO', 'Age-adjusted Rate', '7.7', 'cases per 1,000,000'),
#  (2486, '2011', 'IL', 'Crude Rate', '13.7', 'cases per 1,000,000'),
#  (2495, '2010', 'CT', 'Crude Rate', '12.6', 'cases per 1,000,000'),
#  (2517, '2012', 'IN', 'Crude Rate', '11', 'cases per 1,000,000'),
#  (2539, '2017', 'GA', 'Number', '108', None),
#  (2558, '2010', 'FL', 'Age-adjusted Rate', '8.1', 'cases per 1,000,000'),
#  (2573, '2014', 'IN', 'Number', '73', None),
#  (2577, '2016', 'GA', 'Crude Rate', '9', 'cases per 1,000,000'),
#  (2580, '2011', 'CT', 'Number', '24', None),
#  (2593, '2011', 'IN', 'Number', '73', None),
#  (2600, '2011', 'HI', 'Crude Rate', '18.9', 'cases per 1,000,000'),
#  (2612, '2015', 'IL', 'Number', '157', None),
#  (2613, '2013', 'FL', 'Number', '188', None),
#  (2614, '2012', 'IA', 'Number', '35', None),
#  (2623, '2014', 'FL', 'Crude Rate', '9.6', 'cases per 1,000,000'),
#  (2625, '2014', 'ID', 'Number', '22', None),
#  (2630, '2011', 'CA', 'Number', '403', None),
#  (2635, '2012', 'AL', 'Number', '57', None),
#  (2673, '2016', 'AL', 'Number', '48', None),
#  (2684, '2017', 'CT', 'Number', '38', None),
#  (2685, '2014', 'HI', 'Crude Rate', '16.9', 'cases per 1,000,000'),
#  (2702, '2015', 'AR', 'Crude Rate', '10.1', 'cases per 1,000,000'),
#  (2750, '2015', 'GA', 'Age-adjusted Rate', '9.1', 'cases per 1,000,000'),
#  (2768, '2013', 'KS', 'Age-adjusted Rate', '10.2', 'cases per 1,000,000'),
#  (2781, '2012', 'ID', 'Crude Rate', '13.2', 'cases per 1,000,000'),
#  (2786, '2017', 'ID', 'Number', '27', None),
#  (2800, '2012', 'IL', 'Number', '174', None),
#  (2802, '2015', 'CT', 'Number', '48', None),
#  (2833, '2013', 'CT', 'Crude Rate', '10', 'cases per 1,000,000'),
#  (2835, '2016', 'FL', 'Age-adjusted Rate', '7.5', 'cases per 1,000,000'),
#  (2854, '2012', 'AZ', 'Number', '80', None),
#  (2863, '2013', 'AL', 'Number', '42', None),
#  (2870, '2015', 'IA', 'Number', '41', None),
#  (2889, '2013', 'IA', 'Number', '36', None),
#  (2905, '2012', 'GA', 'Crude Rate', '9.4', 'cases per 1,000,000'),
#  (2907, '2012', 'AR', 'Number', '30', None),
#  (2912, '2011', 'FL', 'Crude Rate', '7.8', 'cases per 1,000,000'),
#  (2913, '2011', 'IL', 'Number', '176', None),
#  (2918, '2013', 'CA', 'Age-adjusted Rate', '10.4', 'cases per 1,000,000'),
#  (2920, '2016', 'CA', 'Age-adjusted Rate', '9.3', 'cases per 1,000,000'),
#  (2921, '2014', 'CO', 'Age-adjusted Rate', '7.8', 'cases per 1,000,000'),
#  (2951, '2013', 'GA', 'Number', '101', None),
#  (2969, '2014', 'AL', 'Number', '57', None),
#  (2971, '2014', 'KS', 'Age-adjusted Rate', '8.4', 'cases per 1,000,000'),
#  (2972, '2010', 'ID', 'Number', '21', None),
#  (2977, '2015', 'FL', 'Crude Rate', '8.6', 'cases per 1,000,000'),
#  (2983, '2015', 'ID', 'Number', '21', None),
#  (2995, '2017', 'FL', 'Number', '179', None),
#  (2996, '2014', 'IA', 'Age-adjusted Rate', '13.7', 'cases per 1,000,000'),
#  (3008, '2013', 'IN', 'Age-adjusted Rate', '9.7', 'cases per 1,000,000'),
#  (3014, '2017', 'CT', 'Crude Rate', '10.6', 'cases per 1,000,000'),
#  (3023, '2016', 'AR', 'Number', '45', None),
#  (3029, '2010', 'AZ', 'Age-adjusted Rate', '8.6', 'cases per 1,000,000'),
#  (3053, '2014', 'CT', 'Age-adjusted Rate', '8.7', 'cases per 1,000,000'),
#  (3054, '2012', 'AL', 'Crude Rate', '11.8', 'cases per 1,000,000'),
#  (3061, '2010', 'CO', 'Age-adjusted Rate', '10.2', 'cases per 1,000,000'),
#  (3126, '2016', 'IL', 'Number', '149', None),
#  (3129, '2013', 'CO', 'Age-adjusted Rate', '9.8', 'cases per 1,000,000'),
#  (3139, '2017', 'AR', 'Age-adjusted Rate', '9.4', 'cases per 1,000,000'),
#  (3144, '2015', 'CT', 'Age-adjusted Rate', '11.1', 'cases per 1,000,000'),
#  (3195, '2016', 'IN', 'Number', '55', None),
#  (3221, '2010', 'KS', 'Age-adjusted Rate', '10.8', 'cases per 1,000,000'),
#  (3231, '2017', 'CA', 'Age-adjusted Rate', '9.3', 'cases per 1,000,000'),
#  (3234, '2015', 'CA', 'Crude Rate', '10', 'cases per 1,000,000'),
#  (3236, '2017', 'IN', 'Age-adjusted Rate', '11', 'cases per 1,000,000'),
#  (3290, '2015', 'NE', 'Crude Rate', '19', 'cases per 1,000,000'),
#  (3295, '2010', 'MD', 'Age-adjusted Rate', '11.4', 'cases per 1,000,000'),
#  (3304, '2013', 'MS', 'Age-adjusted Rate', '19.8', 'cases per 1,000,000'),
#  (3305, '2015', 'LA', 'Age-adjusted Rate', '9.3', 'cases per 1,000,000'),
#  (3320, '2015', 'NY', 'Age-adjusted Rate', '13.1', 'cases per 1,000,000'),
#  (3329, '2012', 'KY', 'Age-adjusted Rate', '5.7', 'cases per 1,000,000'),
#  (3349, '2017', 'OR', 'Crude Rate', '15.7', 'cases per 1,000,000'),
#  (3353, '2014', 'NV', 'Number', '25', None),
#  (3359, '2014', 'OK', 'Crude Rate', '14.4', 'cases per 1,000,000'),
#  (3373, '2011', 'MA', 'Crude Rate', '10.5', 'cases per 1,000,000'),
#  (3376, '2014', 'PA', 'Number', '149', None),
#  (3393, '2013', 'MA', 'Age-adjusted Rate', '8.5', 'cases per 1,000,000'),
#  (3395, '2013', 'OH', 'Age-adjusted Rate', '10.1', 'cases per 1,000,000'),
#  (3405, '2015', 'WI', 'Age-adjusted Rate', '9.8', 'cases per 1,000,000'),
#  (3423, '2015', 'OR', 'Number', '53', None),
#  (3430, '2015', 'MA', 'Age-adjusted Rate', '10.2', 'cases per 1,000,000'),
#  (3446, '2011', 'TN', 'Age-adjusted Rate', '10.3', 'cases per 1,000,000'),
#  (3462, '2014', 'MI', 'Crude Rate', '9.5', 'cases per 1,000,000'),
#  (3464, '2014', 'MO', 'Crude Rate', '14.7', 'cases per 1,000,000'),
#  (3475, '2011', 'OH', 'Crude Rate', '11', 'cases per 1,000,000'),
#  (3489, '2014', 'OR', 'Crude Rate', '19.4', 'cases per 1,000,000'),
#  (3493, '2016', 'OR', 'Age-adjusted Rate', '16', 'cases per 1,000,000'),
#  (3494, '2016', 'MI', 'Crude Rate', '9.4', 'cases per 1,000,000'),
#  (3495, '2016', 'NV', 'Age-adjusted Rate', '12.4', 'cases per 1,000,000'),
#  (3506, '2016', 'NE', 'Age-adjusted Rate', '12.9', 'cases per 1,000,000'),
#  (3510, '2014', 'TX', 'Age-adjusted Rate', '8.3', 'cases per 1,000,000'),
#  (3521, '2014', 'VA', 'Crude Rate', '12.4', 'cases per 1,000,000'),
#  (3530, '2013', 'NJ', 'Crude Rate', '15.1', 'cases per 1,000,000'),
#  (3549, '2011', 'TX', 'Age-adjusted Rate', '8', 'cases per 1,000,000'),
#  (3564, '2010', 'OH', 'Age-adjusted Rate', '11.9', 'cases per 1,000,000'),
#  (3568, '2010', 'WI', 'Number', '63', None),
#  (3581, '2011', 'MS', 'Crude Rate', '18.1', 'cases per 1,000,000'),
#  (3596, '2015', 'NJ', 'Number', '116', None),
#  (3606, '2016', 'KS', 'Age-adjusted Rate', '12.6', 'cases per 1,000,000'),
#  (3612, '2017', 'WA', 'Crude Rate', '14.2', 'cases per 1,000,000'),
#  (3615, '2010', 'MN', 'Age-adjusted Rate', '12.6', 'cases per 1,000,000'),
#  (3621, '2010', 'LA', 'Number', '36', None),
#  (3622, '2010', 'MO', 'Number', '76', None),
#  (3623, '2012', 'VA', 'Age-adjusted Rate', '12.7', 'cases per 1,000,000'),
#  (3626, '2017', 'UT', 'Age-adjusted Rate', '11.5', 'cases per 1,000,000'),
#  (3627, '2014', 'NM', 'Age-adjusted Rate', '12.2', 'cases per 1,000,000'),
#  (3635, '2011', 'MD', 'Number', '71', None),
#  (3643, '2016', 'SC', 'Crude Rate', '12.1', 'cases per 1,000,000'),
#  (3647, '2010', 'UT', 'Age-adjusted Rate', '13.2', 'cases per 1,000,000'),
#  (3652, '2011', 'WV', 'Number', '22', None),
#  (3654, '2015', 'TN', 'Age-adjusted Rate', '8.9', 'cases per 1,000,000'),
#  (3655, '2011', 'LA', 'Age-adjusted Rate', '8.2', 'cases per 1,000,000'),
#  (3656, '2012', 'MD', 'Age-adjusted Rate', '14.9', 'cases per 1,000,000'),
#  (3658, '2016', 'UT', 'Number', '36', None),
#  (3678, '2014', 'WI', 'Number', '77', None),
#  (3687, '2013', 'SC', 'Number', '61', None),
#  (3699, '2010', 'WA', 'Crude Rate', '11.2', 'cases per 1,000,000'),
#  (3739, '2012', 'WI', 'Crude Rate', '13.6', 'cases per 1,000,000'),
#  (3745, '2012', 'OR', 'Crude Rate', '14.4', 'cases per 1,000,000'),
#  (3757, '2016', 'MO', 'Number', '73', None),
#  (3758, '2015', 'WV', 'Number', '25', None),
#  (3759, '2011', 'PA', 'Crude Rate', '10.3', 'cases per 1,000,000'),
#  (3765, '2012', 'NC', 'Number', '123', None),
#  (3767, '2011', 'NE', 'Number', '32', None),
#  (3768, '2017', 'MD', 'Age-adjusted Rate', '10', 'cases per 1,000,000'),
#  (3770, '2017', 'NE', 'Age-adjusted Rate', '10.9', 'cases per 1,000,000'),
#  (3776, '2010', 'NY', 'Age-adjusted Rate', '13.3', 'cases per 1,000,000'),
#  (3780, '2017', 'SC', 'Crude Rate', '13.7', 'cases per 1,000,000'),
#  (3796, '2015', 'MN', 'Number', '61', None),
#  (3799, '2013', 'WV', 'Crude Rate', '16.2', 'cases per 1,000,000'),
#  (3837, '2012', 'MI', 'Number', '107', None),
#  (3855, '2010', 'OR', 'Number', '60', None),
#  (3865, '2011', 'NJ', 'Number', '94', None),
#  (3869, '2015', 'KY', 'Crude Rate', '8.6', 'cases per 1,000,000'),
#  (3877, '2017', 'NY', 'Number', '256', None),
#  (3888, '2015', 'OH', 'Age-adjusted Rate', '12.3', 'cases per 1,000,000'),
#  (3900, '2013', 'NE', 'Crude Rate', '13.4', 'cases per 1,000,000'),
#  (3910, '2014', 'NY', 'Age-adjusted Rate', '14.3', 'cases per 1,000,000'),
#  (3955, '2011', 'MO', 'Age-adjusted Rate', '7.5', 'cases per 1,000,000'),
#  (3971, '2016', 'NM', 'Crude Rate', '13', 'cases per 1,000,000'),
#  (3991, '2016', 'WI', 'Crude Rate', '11.4', 'cases per 1,000,000'),
#  (4022, '2015', 'MS', 'Crude Rate', '17.4', 'cases per 1,000,000'),
#  (4035, '2012', 'MN', 'Crude Rate', '13.4', 'cases per 1,000,000'),
#  (4038, '2010', 'VA', 'Age-adjusted Rate', '8.3', 'cases per 1,000,000'),
#  (4050, '2011', 'NY', 'Age-adjusted Rate', '12.3', 'cases per 1,000,000'),
#  (4055, '2017', 'SC', 'Age-adjusted Rate', '12.4', 'cases per 1,000,000'),
#  (4057, '2016', 'LA', 'Age-adjusted Rate', '8.6', 'cases per 1,000,000'),
#  (4069, '2016', 'VA', 'Age-adjusted Rate', '9.2', 'cases per 1,000,000'),
#  (4073, '2014', 'NC', 'Age-adjusted Rate', '10', 'cases per 1,000,000'),
#  (4076, '2015', 'MO', 'Age-adjusted Rate', '11.4', 'cases per 1,000,000'),
#  (4126, '2013', 'KY', 'Age-adjusted Rate', '7.6', 'cases per 1,000,000'),
#  (4138, '2014', 'WA', 'Crude Rate', '13.2', 'cases per 1,000,000'),
#  (4149, '2015', 'OK', 'Age-adjusted Rate', '12.9', 'cases per 1,000,000'),
#  (4168, '2016', 'OH', 'Age-adjusted Rate', '10', 'cases per 1,000,000'),
#  (4174, '2014', 'MA', 'Age-adjusted Rate', '9.6', 'cases per 1,000,000'),
#  (4175, '2013', 'MD', 'Crude Rate', '12', 'cases per 1,000,000'),
#  (4176, '2015', 'MD', 'Number', '79', None),
#  (4183, '2010', 'NC', 'Age-adjusted Rate', '10.2', 'cases per 1,000,000'),
#  (4190, '2013', 'MN', 'Number', '79', None),
#  (4200, '2012', 'OK', 'Age-adjusted Rate', '13.5', 'cases per 1,000,000'),
#  (4203, '2016', 'OK', 'Age-adjusted Rate', '10.8', 'cases per 1,000,000'),
#  (4215, '2010', 'WV', 'Crude Rate', '13', 'cases per 1,000,000'),
#  (4290, '2017', 'TX', 'Crude Rate', '8.2', 'cases per 1,000,000'),
#  (4298, '2013', 'MI', 'Number', '110', None),
#  (4318, '2012', 'MA', 'Crude Rate', '8.7', 'cases per 1,000,000'),
#  (4320, '2016', 'WV', 'Age-adjusted Rate', '12.6', 'cases per 1,000,000'),
#  (4327, '2011', 'NM', 'Number', '26', None),
#  (4334, '2010', 'VA', 'Crude Rate', '8.6', 'cases per 1,000,000'),
#  (4344, '2011', 'OR', 'Number', '46', None),
#  (4347, '2010', 'MI', 'Age-adjusted Rate', '10.2', 'cases per 1,000,000'),
#  (4353, '2017', 'WI', 'Age-adjusted Rate', '8.7', 'cases per 1,000,000'),
#  (4355, '2010', 'MS', 'Crude Rate', '16.5', 'cases per 1,000,000'),
#  (4404, '2014', 'MS', 'Crude Rate', '16', 'cases per 1,000,000'),
#  (4414, '2010', 'SC', 'Number', '66', None),
#  (4417, '2012', 'OH', 'Age-adjusted Rate', '11.3', 'cases per 1,000,000'),
#  (4418, '2011', 'KY', 'Crude Rate', '7.6', 'cases per 1,000,000'),
#  (4438, '2017', 'PA', 'Age-adjusted Rate', '8.7', 'cases per 1,000,000'),
#  (4447, '2017', 'KS', 'Age-adjusted Rate', '12.2', 'cases per 1,000,000'),
#  (4468, '2016', 'WA', 'Age-adjusted Rate', '9.8', 'cases per 1,000,000'),
#  (4469, '2015', 'PA', 'Age-adjusted Rate', '10.2', 'cases per 1,000,000'),
#  (4470, '2013', 'NV', 'Age-adjusted Rate', '9.6', 'cases per 1,000,000'),
#  (4488, '2014', 'MN', 'Crude Rate', '12.1', 'cases per 1,000,000'),
#  (4495, '2013', 'OR', 'Crude Rate', '15.8', 'cases per 1,000,000'),
#  (4506, '2012', 'TN', 'Number', '58', None),
#  (4522, '2012', 'WA', 'Age-adjusted Rate', '10.5', 'cases per 1,000,000'),
#  (4526, '2017', 'MN', 'Age-adjusted Rate', '8', 'cases per 1,000,000'),
#  (4533, '2017', 'NC', 'Number', '116', None),
#  (4536, '2014', 'MI', 'Age-adjusted Rate', '8.7', 'cases per 1,000,000'),
#  (4548, '2014', 'UT', 'Age-adjusted Rate', '12.5', 'cases per 1,000,000'),
#  (4565, '2010', 'OK', 'Crude Rate', '9.1', 'cases per 1,000,000'),
#  (4611, '2012', 'PA', 'Crude Rate', '11.4', 'cases per 1,000,000'),
#  (4622, '2013', 'UT', 'Number', '31', None),
#  (4642, '2011', 'SD', 'Crude Rate', '24.3', 'cases per 1,000,000'),
#  (4643, '2017', 'NV', 'Number', '32', None),
#  (4644, '2016', 'MA', 'Crude Rate', '12.6', 'cases per 1,000,000'),
#  (4652, '2017', 'MI', 'Number', '119', None),
#  (4658, '2010', 'MA', 'Age-adjusted Rate', '6.5', 'cases per 1,000,000'),
#  (4668, '2010', 'TX', 'Age-adjusted Rate', '8.2', 'cases per 1,000,000'),
#  (4697, '2016', 'PA', 'Crude Rate', '10', 'cases per 1,000,000'),
#  (4712, '2015', 'NM', 'Age-adjusted Rate', '12.1', 'cases per 1,000,000'),
#  (4723, '2011', 'NV', 'Crude Rate', '7.3', 'cases per 1,000,000'),
#  (4727, '2017', 'KY', 'Age-adjusted Rate', '6.6', 'cases per 1,000,000'),
#  (4731, '2012', 'MS', 'Number', '45', None),
#  (4734, '2012', 'LA', 'Age-adjusted Rate', '8.6', 'cases per 1,000,000'),
#  (4755, '2011', 'WI', 'Age-adjusted Rate', '10.1', 'cases per 1,000,000'),
#  (4757, '2010', 'PA', 'Number', '132', None),
#  (4759, '2016', 'MD', 'Crude Rate', '13.1', 'cases per 1,000,000'),
#  (4779, '2016', 'MN', 'Number', '76', None),
#  (4801, '2015', 'NV', 'Crude Rate', '8.3', 'cases per 1,000,000'),
#  (4802, '2016', 'OR', 'Crude Rate', '18.3', 'cases per 1,000,000'),
#  (4824, '2012', 'SC', 'Number', '81', None),
#  (4829, '2017', 'OK', 'Crude Rate', '13.7', 'cases per 1,000,000'),
#  (4837, '2012', 'OH', 'Number', '145', None),
#  (4841, '2014', 'OH', 'Crude Rate', '10', 'cases per 1,000,000'),
#  (4858, '2017', 'NJ', 'Crude Rate', '12.2', 'cases per 1,000,000'),
#  (4868, '2012', 'NY', 'Crude Rate', '14.5', 'cases per 1,000,000'),
#  (4870, '2010', 'NE', 'Number', '26', None),
#  (4873, '2010', 'OH', 'Crude Rate', '13.1', 'cases per 1,000,000'),
#  (4875, '2013', 'VA', 'Number', '87', None),
#  (4893, '2011', 'NC', 'Number', '99', None),
#  (4897, '2010', 'TN', 'Age-adjusted Rate', '10.4', 'cases per 1,000,000'),
#  (4898, '2013', 'OH', 'Crude Rate', '11.2', 'cases per 1,000,000'),
#  (4902, '2010', 'MN', 'Crude Rate', '13.8', 'cases per 1,000,000'),
#  (4905, '2016', 'KS', 'Crude Rate', '14.1', 'cases per 1,000,000'),
#  (4911, '2017', 'UT', 'Crude Rate', '10', 'cases per 1,000,000'),
#  (4926, '2015', 'MA', 'Crude Rate', '12.4', 'cases per 1,000,000'),
#  (4931, '2017', 'NM', 'Crude Rate', '19.6', 'cases per 1,000,000'),
#  (4939, '2015', 'SC', 'Age-adjusted Rate', '10.5', 'cases per 1,000,000'),
#  (4941, '2012', 'MD', 'Crude Rate', '15.5', 'cases per 1,000,000'),
#  (4948, '2011', 'LA', 'Crude Rate', '8.1', 'cases per 1,000,000'),
#  (4953, '2011', 'NJ', 'Crude Rate', '10.7', 'cases per 1,000,000'),
#  (4956, '2011', 'WA', 'Number', '82', None),
#  (4968, '2014', 'NJ', 'Crude Rate', '12.4', 'cases per 1,000,000'),
#  (4990, '2015', 'TX', 'Number', '241', None),
#  (4992, '2016', 'NE', 'Crude Rate', '14.7', 'cases per 1,000,000'),
#  (4996, '2011', 'TX', 'Crude Rate', '7.6', 'cases per 1,000,000'),
#  (4998, '2014', 'TX', 'Crude Rate', '7.9', 'cases per 1,000,000'),
#  (5005, '2013', 'NE', 'Number', '25', None),
#  (5007, '2013', 'TX', 'Age-adjusted Rate', '8.6', 'cases per 1,000,000'),
#  (5010, '2013', 'MS', 'Crude Rate', '20.4', 'cases per 1,000,000'),
#  (5014, '2015', 'NE', 'Age-adjusted Rate', '17', 'cases per 1,000,000'),
#  (5022, '2015', 'LA', 'Crude Rate', '10.1', 'cases per 1,000,000'),
#  (5025, '2012', 'WA', 'Crude Rate', '11.2', 'cases per 1,000,000'),
#  (5032, '2015', 'NY', 'Crude Rate', '14.9', 'cases per 1,000,000'),
#  (5036, '2012', 'KY', 'Crude Rate', '5.7', 'cases per 1,000,000'),
#  (5044, '2013', 'NJ', 'Age-adjusted Rate', '13.3', 'cases per 1,000,000'),
#  (5046, '2012', 'NM', 'Crude Rate', '12.9', 'cases per 1,000,000'),
#  (5052, '2014', 'UT', 'Crude Rate', '10.5', 'cases per 1,000,000'),
#  (5060, '2016', 'TN', 'Number', '78', None),
#  (5066, '2013', 'TN', 'Age-adjusted Rate', '8.8', 'cases per 1,000,000'),
#  (5068, '2012', 'WI', 'Number', '78', None),
#  (5072, '2017', 'MD', 'Crude Rate', '11.2', 'cases per 1,000,000'),
#  (5075, '2017', 'OH', 'Number', '135', None),
#  (5099, '2013', 'MA', 'Crude Rate', '10', 'cases per 1,000,000'),
#  (5100, '2016', 'WI', 'Number', '66', None),
#  (5107, '2013', 'WV', 'Number', '30', None),
#  (5116, '2012', 'VA', 'Crude Rate', '13.1', 'cases per 1,000,000'),
#  (5132, '2015', 'MS', 'Number', '52', None),
#  (5143, '2012', 'MN', 'Number', '72', None),
#  (5153, '2011', 'TN', 'Crude Rate', '10.8', 'cases per 1,000,000'),
#  (5179, '2010', 'WA', 'Number', '75', None),
#  (5183, '2014', 'VA', 'Number', '103', None),
#  (5196, '2014', 'OR', 'Age-adjusted Rate', '16.7', 'cases per 1,000,000'),
#  (5208, '2010', 'MD', 'Crude Rate', '12.3', 'cases per 1,000,000'),
#  (5217, '2011', 'SC', 'Age-adjusted Rate', '15.1', 'cases per 1,000,000'),
#  (5232, '2011', 'OH', 'Number', '127', None),
#  (5280, '2011', 'NY', 'Crude Rate', '13.2', 'cases per 1,000,000'),
#  (5282, '2011', 'MS', 'Number', '54', None),
#  (5287, '2016', 'NC', 'Number', '103', None),
#  (5299, '2011', 'MA', 'Number', '69', None),
#  (5315, '2016', 'NC', 'Age-adjusted Rate', '9.9', 'cases per 1,000,000'),
#  (5319, '2017', 'WA', 'Number', '105', None),
#  (5322, '2016', 'KY', 'Age-adjusted Rate', '10.2', 'cases per 1,000,000'),
#  (5329, '2015', 'NJ', 'Crude Rate', '12.9', 'cases per 1,000,000'),
#  (5345, '2013', 'NC', 'Crude Rate', '11.4', 'cases per 1,000,000'),
#  (5366, '2012', 'OK', 'Crude Rate', '14.2', 'cases per 1,000,000'),
#  (5379, '2017', 'TN', 'Age-adjusted Rate', '10.2', 'cases per 1,000,000'),
#  (5391, '2014', 'MO', 'Number', '89', None),
#  (5394, '2010', 'OR', 'Crude Rate', '15.7', 'cases per 1,000,000'),
#  (5414, '2016', 'MI', 'Number', '93', None),
#  (5435, '2012', 'NV', 'Age-adjusted Rate', '7.1', 'cases per 1,000,000'),
#  (5459, '2011', 'OK', 'Number', '44', None),
#  (5461, '2010', 'NM', 'Age-adjusted Rate', '10.3', 'cases per 1,000,000'),
#  (5488, '2014', 'OK', 'Number', '56', None),
#  (5496, '2012', 'UT', 'Age-adjusted Rate', '12.8', 'cases per 1,000,000'),
#  (5499, '2017', 'OR', 'Number', '65', None),
#  (5514, '2016', 'MN', 'Crude Rate', '13.8', 'cases per 1,000,000'),
#  (5517, '2016', 'TX', 'Age-adjusted Rate', '7.2', 'cases per 1,000,000'),
#  (5538, '2016', 'MS', 'Age-adjusted Rate', '21', 'cases per 1,000,000'),
#  (5567, '2013', 'LA', 'Age-adjusted Rate', '11.7', 'cases per 1,000,000'),
#  (5574, '2010', 'UT', 'Crude Rate', '10.1', 'cases per 1,000,000'),
#  (5586, '2015', 'TN', 'Crude Rate', '9.7', 'cases per 1,000,000'),
#  (5602, '2017', 'MN', 'Number', '55', None),
#  (5613, '2014', 'MI', 'Number', '94', None),
#  (5626, '2014', 'MD', 'Age-adjusted Rate', '13.6', 'cases per 1,000,000'),
#  (5634, '2016', 'NJ', 'Crude Rate', '11.4', 'cases per 1,000,000'),
#  (5643, '2017', 'NY', 'Crude Rate', '12.9', 'cases per 1,000,000'),
#  (5659, '2010', 'KY', 'Age-adjusted Rate', '9.8', 'cases per 1,000,000'),
#  (5681, '2016', 'NY', 'Crude Rate', '13.8', 'cases per 1,000,000'),
#  (5688, '2012', 'MA', 'Age-adjusted Rate', '7.3', 'cases per 1,000,000'),
#  (5694, '2012', 'OR', 'Age-adjusted Rate', '12.7', 'cases per 1,000,000'),
#  (5698, '2011', 'PA', 'Age-adjusted Rate', '8.6', 'cases per 1,000,000'),
#  (5713, '2017', 'MA', 'Age-adjusted Rate', '8.9', 'cases per 1,000,000'),
#  (5722, '2010', 'MS', 'Age-adjusted Rate', '15.9', 'cases per 1,000,000'),
#  (5726, '2017', 'MS', 'Number', '47', None),
#  (5734, '2014', 'MS', 'Age-adjusted Rate', '14.5', 'cases per 1,000,000'),
#  (5747, '2013', 'OK', 'Number', '50', None),
#  (5750, '2014', 'TN', 'Number', '64', None),
#  (5754, '2012', 'SC', 'Crude Rate', '17.1', 'cases per 1,000,000'),
#  (5757, '2012', 'NE', 'Number', '26', None),
#  (5759, '2015', 'TX', 'Crude Rate', '8.8', 'cases per 1,000,000'),
#  (5763, '2017', 'WV', 'Number', '24', None),
#  (5777, '2013', 'VA', 'Crude Rate', '10.5', 'cases per 1,000,000'),
#  (5785, '2016', 'OK', 'Crude Rate', '11', 'cases per 1,000,000'),
#  (5792, '2011', 'KY', 'Age-adjusted Rate', '7.1', 'cases per 1,000,000'),
#  (5804, '2017', 'MI', 'Crude Rate', '11.9', 'cases per 1,000,000'),
#  (5813, '2017', 'VA', 'Number', '71', None),
#  (5825, '2015', 'VA', 'Number', '90', None),
#  (5844, '2011', 'UT', 'Number', '44', None),
#  (5864, '2017', 'TX', 'Age-adjusted Rate', '8.3', 'cases per 1,000,000'),
#  (5887, '2012', 'MS', 'Crude Rate', '15.1', 'cases per 1,000,000'),
#  (5888, '2010', 'NJ', 'Number', '80', None),
#  (5890, '2010', 'MN', 'Number', '73', None),
#  (5913, '2012', 'MD', 'Number', '91', None),
#  (5915, '2011', 'MI', 'Number', '113', None),
#  (5917, '2013', 'WI', 'Number', '75', None),
#  (5919, '2017', 'NC', 'Crude Rate', '11.3', 'cases per 1,000,000'),
#  (5939, '2010', 'OK', 'Number', '34', None),
#  (5944, '2015', 'NV', 'Age-adjusted Rate', '8.2', 'cases per 1,000,000'),
#  (5964, '2016', 'OH', 'Crude Rate', '11.5', 'cases per 1,000,000'),
#  (5968, '2013', 'MD', 'Age-adjusted Rate', '11.1', 'cases per 1,000,000'),
#  (5980, '2010', 'NC', 'Crude Rate', '10.6', 'cases per 1,000,000'),
#  (5998, '2012', 'NJ', 'Crude Rate', '11.6', 'cases per 1,000,000'),
#  (6009, '2011', 'MN', 'Number', '60', None),
#  (6014, '2011', 'MD', 'Crude Rate', '12.2', 'cases per 1,000,000'),
#  (6020, '2010', 'NE', 'Crude Rate', '14.2', 'cases per 1,000,000'),
#  (6043, '2015', 'KY', 'Age-adjusted Rate', '7.8', 'cases per 1,000,000'),
#  (6050, '2014', 'NC', 'Crude Rate', '10.7', 'cases per 1,000,000'),
#  (6063, '2016', 'VA', 'Crude Rate', '9.6', 'cases per 1,000,000'),
#  (6071, '2016', 'PA', 'Number', '128', None),
#  (6079, '2010', 'WV', 'Age-adjusted Rate', '10.6', 'cases per 1,000,000'),
#  (6088, '2013', 'OR', 'Number', '62', None),
#  (6089, '2015', 'NC', 'Number', '96', None),
#  (6091, '2015', 'NM', 'Crude Rate', '12.5', 'cases per 1,000,000'),
#  (6092, '2012', 'PA', 'Number', '146', None),
#  (6093, '2011', 'NM', 'Crude Rate', '12.5', 'cases per 1,000,000'),
#  (6098, '2012', 'TN', 'Crude Rate', '9', 'cases per 1,000,000'),
#  (6121, '2013', 'NY', 'Age-adjusted Rate', '13', 'cases per 1,000,000'),
#  (6128, '2010', 'PA', 'Crude Rate', '10.4', 'cases per 1,000,000'),
#  (6138, '2017', 'MO', 'Number', '68', None),
#  (6173, '2014', 'LA', 'Number', '61', None),
#  (6182, '2013', 'UT', 'Crude Rate', '10.7', 'cases per 1,000,000'),
#  (6192, '2013', 'MI', 'Crude Rate', '11.1', 'cases per 1,000,000'),
#  (6197, '2012', 'NC', 'Age-adjusted Rate', '12', 'cases per 1,000,000'),
#  (6214, '2014', 'SC', 'Number', '74', None),
#  (6283, '2013', 'MO', 'Number', '53', None),
#  (6294, '2014', 'NJ', 'Age-adjusted Rate', '10.9', 'cases per 1,000,000'),
#  (6295, '2011', 'NV', 'Age-adjusted Rate', '7.8', 'cases per 1,000,000'),
#  (6303, '2014', 'WA', 'Age-adjusted Rate', '12.6', 'cases per 1,000,000'),
#  (6315, '2016', 'MD', 'Age-adjusted Rate', '12.1', 'cases per 1,000,000'),
#  (6334, '2017', 'NM', 'Age-adjusted Rate', '18.2', 'cases per 1,000,000'),
#  (6344, '2013', 'MN', 'Crude Rate', '14.6', 'cases per 1,000,000'),
#  (6350, '2015', 'MI', 'Number', '112', None),
#  (6356, '2016', 'MA', 'Age-adjusted Rate', '10.9', 'cases per 1,000,000'),
#  (6357, '2015', 'MD', 'Crude Rate', '13.2', 'cases per 1,000,000'),
#  (6382, '2010', 'SC', 'Crude Rate', '14.3', 'cases per 1,000,000'),
#  (6384, '2011', 'SD', 'Age-adjusted Rate', '19.1', 'cases per 1,000,000'),
#  (6403, '2016', 'SC', 'Age-adjusted Rate', '11', 'cases per 1,000,000'),
#  (6405, '2017', 'OK', 'Number', '54', None),
#  (6412, '2015', 'UT', 'Number', '40', None),
#  (6418, '2017', 'NJ', 'Age-adjusted Rate', '11', 'cases per 1,000,000'),
#  (6422, '2014', 'OH', 'Number', '116', None),
#  (6469, '2014', 'MN', 'Age-adjusted Rate', '10.9', 'cases per 1,000,000'),
#  (6497, '2011', 'VA', 'Number', '89', None),
#  (6510, '2017', 'MN', 'Crude Rate', '9.9', 'cases per 1,000,000'),
#  (6514, '2014', 'KY', 'Age-adjusted Rate', '7.5', 'cases per 1,000,000'),
#  (6547, '2016', 'TN', 'Crude Rate', '11.7', 'cases per 1,000,000'),
#  (6557, '2015', 'WA', 'Age-adjusted Rate', '11.5', 'cases per 1,000,000'),
#  (6583, '2011', 'MO', 'Number', '48', None),
#  (6586, '2011', 'SC', 'Crude Rate', '15', 'cases per 1,000,000'),
#  (6594, '2012', 'NM', 'Number', '27', None),
#  (6597, '2012', 'NM', 'Age-adjusted Rate', '12.1', 'cases per 1,000,000'),
#  (6607, '2013', 'PA', 'Number', '157', None),
#  (6611, '2012', 'NY', 'Age-adjusted Rate', '13', 'cases per 1,000,000'),
#  (6631, '2013', 'TN', 'Crude Rate', '9.5', 'cases per 1,000,000'),
#  (6686, '2010', 'UT', 'Number', '28', None),
#  (6688, '2015', 'SC', 'Crude Rate', '11.6', 'cases per 1,000,000'),
#  (6689, '2015', 'TN', 'Number', '64', None),
#  (6704, '2016', 'NJ', 'Number', '102', None),
#  (6707, '2017', 'TN', 'Crude Rate', '10.7', 'cases per 1,000,000'),
#  (6716, '2011', 'NY', 'Number', '257', None),
#  (6717, '2017', 'LA', 'Age-adjusted Rate', '8.2', 'cases per 1,000,000'),
#  (6722, '2014', 'NC', 'Number', '106', None),
#  (6729, '2016', 'LA', 'Number', '42', None),
#  (6746, '2013', 'OK', 'Age-adjusted Rate', '12.9', 'cases per 1,000,000'),
#  (6750, '2012', 'OK', 'Number', '54', None),
#  (6752, '2010', 'KY', 'Crude Rate', '10.1', 'cases per 1,000,000'),
#  (6766, '2013', 'TX', 'Crude Rate', '8.1', 'cases per 1,000,000'),
#  (6775, '2011', 'OK', 'Crude Rate', '11.6', 'cases per 1,000,000'),
#  (6780, '2016', 'NY', 'Age-adjusted Rate', '12.5', 'cases per 1,000,000'),
#  (6810, '2010', 'NY', 'Number', '283', None),
#  (6813, '2016', 'MO', 'Age-adjusted Rate', '11.7', 'cases per 1,000,000'),
#  (6824, '2011', 'NE', 'Age-adjusted Rate', '15.4', 'cases per 1,000,000'),
#  (6832, '2016', 'TX', 'Crude Rate', '7', 'cases per 1,000,000'),
#  (6849, '2010', 'NV', 'Crude Rate', '10', 'cases per 1,000,000'),
#  (6857, '2010', 'TN', 'Crude Rate', '10.6', 'cases per 1,000,000'),
#  (6859, '2014', 'MA', 'Number', '76', None),
#  (6886, '2012', 'MO', 'Crude Rate', '12.5', 'cases per 1,000,000'),
#  (6892, '2011', 'NJ', 'Age-adjusted Rate', '9.5', 'cases per 1,000,000'),
#  (6926, '2017', 'OH', 'Crude Rate', '11.6', 'cases per 1,000,000'),
#  (6931, '2016', 'NV', 'Number', '37', None),
#  (6932, '2017', 'NY', 'Age-adjusted Rate', '11.6', 'cases per 1,000,000'),
#  (6939, '2016', 'NE', 'Number', '28', None),
#  (6940, '2011', 'TX', 'Number', '195', None),
#  (6947, '2014', 'TX', 'Number', '212', None),
#  (6957, '2015', 'OH', 'Number', '159', None),
#  (6962, '2012', 'VA', 'Number', '107', None),
#  (6979, '2012', 'NV', 'Crude Rate', '7.2', 'cases per 1,000,000'),
#  (7021, '2010', 'WI', 'Age-adjusted Rate', '10', 'cases per 1,000,000'),
#  (7026, '2016', 'MN', 'Age-adjusted Rate', '12.3', 'cases per 1,000,000'),
#  (7032, '2016', 'NC', 'Crude Rate', '10.2', 'cases per 1,000,000'),
#  (7035, '2010', 'MO', 'Age-adjusted Rate', '11.9', 'cases per 1,000,000'),
#  (7036, '2017', 'MA', 'Crude Rate', '10.4', 'cases per 1,000,000'),
#  (7054, '2016', 'MS', 'Crude Rate', '21.7', 'cases per 1,000,000'),
#  (7060, '2016', 'KS', 'Number', '41', None),
#  (7064, '2015', 'NJ', 'Age-adjusted Rate', '11.6', 'cases per 1,000,000'),
#  (7068, '2010', 'LA', 'Age-adjusted Rate', '7.8', 'cases per 1,000,000'),
#  (7071, '2014', 'NM', 'Number', '28', None),
#  (7075, '2011', 'LA', 'Number', '37', None),
#  (7079, '2013', 'LA', 'Crude Rate', '12.1', 'cases per 1,000,000'),
#  (7080, '2017', 'UT', 'Number', '31', None),
#  (7085, '2013', 'NC', 'Age-adjusted Rate', '10.8', 'cases per 1,000,000'),
#  (7093, '2012', 'TX', 'Age-adjusted Rate', '8.4', 'cases per 1,000,000'),
#  (7111, '2016', 'UT', 'Age-adjusted Rate', '14.5', 'cases per 1,000,000'),
#  (7173, '2013', 'MS', 'Number', '61', None),
#  (7182, '2013', 'SC', 'Age-adjusted Rate', '11.7', 'cases per 1,000,000'),
#  (7183, '2010', 'MD', 'Number', '71', None),
#  (7184, '2010', 'NM', 'Crude Rate', '10.7', 'cases per 1,000,000'),
#  (7197, '2015', 'LA', 'Number', '47', None),
#  (7198, '2015', 'NY', 'Number', '295', None),
#  (7214, '2012', 'KY', 'Number', '25', None),
#  (7232, '2014', 'UT', 'Number', '31', None),
#  (7233, '2012', 'WA', 'Number', '77', None),
#  (7234, '2014', 'NV', 'Age-adjusted Rate', '8.2', 'cases per 1,000,000'),
#  (7243, '2017', 'MD', 'Number', '68', None),
#  (7250, '2014', 'MD', 'Crude Rate', '14.6', 'cases per 1,000,000'),
#  (7254, '2012', 'UT', 'Crude Rate', '9.8', 'cases per 1,000,000'),
#  (7263, '2014', 'PA', 'Age-adjusted Rate', '9.9', 'cases per 1,000,000'),
#  (7280, '2015', 'MN', 'Age-adjusted Rate', '9.8', 'cases per 1,000,000'),
#  (7286, '2013', 'MA', 'Number', '67', None),
#  (7287, '2013', 'NY', 'Crude Rate', '14.4', 'cases per 1,000,000'),
#  (7292, '2015', 'WI', 'Number', '66', None),
#  (7303, '2013', 'WA', 'Age-adjusted Rate', '11.6', 'cases per 1,000,000'),
#  (7306, '2013', 'OH', 'Number', '130', None),
#  (7315, '2014', 'NJ', 'Number', '111', None),
#  (7316, '2015', 'MA', 'Number', '84', None),
#  (7333, '2016', 'KY', 'Crude Rate', '10.8', 'cases per 1,000,000'),
#  (7342, '2011', 'NC', 'Crude Rate', '10.3', 'cases per 1,000,000'),
#  (7348, '2011', 'WA', 'Crude Rate', '12', 'cases per 1,000,000'),
#  (7349, '2012', 'MI', 'Age-adjusted Rate', '9.6', 'cases per 1,000,000'),
#  (7351, '2010', 'OR', 'Age-adjusted Rate', '13.7', 'cases per 1,000,000'),
#  (7354, '2017', 'NM', 'Number', '41', None),
#  (7389, '2015', 'VA', 'Crude Rate', '10.7', 'cases per 1,000,000'),
#  (7420, '2012', 'TX', 'Crude Rate', '7.9', 'cases per 1,000,000'),
#  (7421, '2011', 'NM', 'Age-adjusted Rate', '11.6', 'cases per 1,000,000'),
#  (7425, '2010', 'NJ', 'Crude Rate', '9.1', 'cases per 1,000,000'),
#  (7433, '2012', 'MS', 'Age-adjusted Rate', '14.6', 'cases per 1,000,000'),
#  (7442, '2016', 'WV', 'Number', '25', None),
#  (7444, '2011', 'VA', 'Crude Rate', '11', 'cases per 1,000,000'),
#  (7448, '2013', 'WI', 'Crude Rate', '13.1', 'cases per 1,000,000'),
#  (7449, '2011', 'OR', 'Age-adjusted Rate', '10.3', 'cases per 1,000,000'),
#  (7451, '2011', 'WI', 'Number', '64', None),
#  (7458, '2010', 'PA', 'Age-adjusted Rate', '9.1', 'cases per 1,000,000'),
#  (7463, '2010', 'MI', 'Number', '105', None),
#  (7467, '2017', 'KY', 'Number', '32', None),
#  (7493, '2012', 'NE', 'Crude Rate', '14', 'cases per 1,000,000'),
#  (7524, '2014', 'WI', 'Age-adjusted Rate', '11.9', 'cases per 1,000,000'),
#  (7537, '2013', 'VA', 'Age-adjusted Rate', '10.5', 'cases per 1,000,000'),
#  (7551, '2011', 'MD', 'Age-adjusted Rate', '11.6', 'cases per 1,000,000'),
#  (7552, '2011', 'WV', 'Age-adjusted Rate', '9.9', 'cases per 1,000,000'),
#  (7560, '2016', 'NJ', 'Age-adjusted Rate', '10.3', 'cases per 1,000,000'),
#  (7564, '2010', 'NE', 'Age-adjusted Rate', '12.3', 'cases per 1,000,000'),
#  (7567, '2013', 'PA', 'Crude Rate', '12.3', 'cases per 1,000,000'),
#  (7569, '2014', 'NE', 'Age-adjusted Rate', '13.9', 'cases per 1,000,000'),
#  (7598, '2015', 'PA', 'Number', '155', None),
#  (7604, '2016', 'WA', 'Number', '78', None),
#  (7605, '2013', 'NV', 'Number', '27', None),
#  (7613, '2014', 'NY', 'Number', '302', None),
#  (7621, '2013', 'MO', 'Crude Rate', '8.8', 'cases per 1,000,000'),
#  (7632, '2015', 'OR', 'Age-adjusted Rate', '11.2', 'cases per 1,000,000'),
#  (7636, '2017', 'MO', 'Crude Rate', '11.1', 'cases per 1,000,000'),
#  (7637, '2012', 'TN', 'Age-adjusted Rate', '8.3', 'cases per 1,000,000'),
#  (7640, '2013', 'WA', 'Crude Rate', '12.5', 'cases per 1,000,000'),
#  (7675, '2017', 'NC', 'Age-adjusted Rate', '10.9', 'cases per 1,000,000'),
#  (7696, '2013', 'MN', 'Age-adjusted Rate', '13.1', 'cases per 1,000,000'),
#  (7704, '2015', 'MI', 'Crude Rate', '11.3', 'cases per 1,000,000'),
#  (7708, '2011', 'TN', 'Number', '69', None),
#  (7717, '2015', 'MD', 'Age-adjusted Rate', '12.2', 'cases per 1,000,000'),
#  (7726, '2014', 'SC', 'Crude Rate', '15.3', 'cases per 1,000,000'),
#  (7730, '2015', 'TX', 'Age-adjusted Rate', '9.1', 'cases per 1,000,000'),
#  (7737, '2014', 'LA', 'Crude Rate', '13.1', 'cases per 1,000,000'),
#  (7743, '2017', 'NV', 'Age-adjusted Rate', '9.5', 'cases per 1,000,000'),
#  (7753, '2012', 'NJ', 'Age-adjusted Rate', '10.5', 'cases per 1,000,000'),
#  (7769, '2015', 'UT', 'Crude Rate', '13.4', 'cases per 1,000,000'),
#  (7774, '2017', 'MI', 'Age-adjusted Rate', '10.3', 'cases per 1,000,000'),
#  (7775, '2010', 'MA', 'Number', '50', None),
#  (7803, '2017', 'PA', 'Number', '132', None),
#  (7810, '2010', 'TX', 'Number', '192', None),
#  (7837, '2015', 'NM', 'Number', '26', None),
#  (7855, '2012', 'LA', 'Number', '40', None),
#  (7881, '2014', 'KY', 'Crude Rate', '7.9', 'cases per 1,000,000'),
#  (7896, '2017', 'LA', 'Crude Rate', '8.3', 'cases per 1,000,000'),
#  (7899, '2017', 'MS', 'Crude Rate', '15.8', 'cases per 1,000,000'),
#  (7900, '2017', 'NE', 'Number', '23', None),
#  (7909, '2014', 'TN', 'Crude Rate', '9.8', 'cases per 1,000,000'),
#  (7911, '2017', 'WI', 'Number', '59', None),
#  (7937, '2012', 'SC', 'Age-adjusted Rate', '16.2', 'cases per 1,000,000'),
#  (7942, '2010', 'SC', 'Age-adjusted Rate', '13.9', 'cases per 1,000,000'),
#  (7966, '2011', 'MN', 'Crude Rate', '11.2', 'cases per 1,000,000'),
#  (7976, '2017', 'VA', 'Crude Rate', '8.4', 'cases per 1,000,000'),
#  (7984, '2015', 'MO', 'Number', '72', None),
#  (7996, '2015', 'NC', 'Crude Rate', '9.6', 'cases per 1,000,000'),
#  (8001, '2011', 'UT', 'Crude Rate', '15.6', 'cases per 1,000,000'),
#  (8003, '2016', 'VA', 'Number', '81', None),
#  (8011, '2016', 'KY', 'Number', '48', None),
#  (8032, '2010', 'NV', 'Age-adjusted Rate', '9.7', 'cases per 1,000,000'),
#  (8039, '2012', 'MO', 'Age-adjusted Rate', '11.6', 'cases per 1,000,000'),
#  (8063, '2011', 'MI', 'Crude Rate', '11.4', 'cases per 1,000,000'),
#  (8085, '2016', 'OH', 'Number', '133', None),
#  (8092, '2015', 'OK', 'Number', '52', None),
#  (8100, '2013', 'KY', 'Number', '36', None),
#  (8102, '2015', 'WV', 'Age-adjusted Rate', '12.5', 'cases per 1,000,000'),
#  (8108, '2013', 'UT', 'Age-adjusted Rate', '13.4', 'cases per 1,000,000'),
#  (8110, '2013', 'OK', 'Crude Rate', '13', 'cases per 1,000,000'),
#  (8114, '2010', 'NC', 'Number', '101', None),
#  (8120, '2017', 'WV', 'Crude Rate', '13.2', 'cases per 1,000,000'),
#  (8122, '2013', 'MI', 'Age-adjusted Rate', '10.4', 'cases per 1,000,000'),
#  (8139, '2012', 'NJ', 'Number', '103', None),
#  (8140, '2016', 'OK', 'Number', '43', None),
#  (8151, '2012', 'NC', 'Crude Rate', '12.6', 'cases per 1,000,000'),
#  (8184, '2017', 'KS', 'Number', '43', None),
#  (8204, '2016', 'MS', 'Number', '65', None),
#  (8218, '2014', 'NM', 'Crude Rate', '13.4', 'cases per 1,000,000'),
#  (8224, '2013', 'MD', 'Number', '71', None),
#  (8232, '2012', 'PA', 'Age-adjusted Rate', '9.6', 'cases per 1,000,000'),
#  (8247, '2015', 'WI', 'Crude Rate', '11.4', 'cases per 1,000,000'),
#  (8301, '2014', 'MD', 'Number', '87', None),
#  (8307, '2015', 'KY', 'Number', '38', None),
#  (8330, '2012', 'OR', 'Number', '56', None),
#  (8338, '2014', 'VA', 'Age-adjusted Rate', '12', 'cases per 1,000,000'),
#  (8350, '2012', 'WI', 'Age-adjusted Rate', '11.6', 'cases per 1,000,000'),
#  (8371, '2013', 'NY', 'Number', '283', None),
#  (8382, '2011', 'PA', 'Number', '131', None),
#  (8394, '2017', 'MA', 'Number', '71', None),
#  (8403, '2017', 'SC', 'Number', '69', None),
#  (8405, '2011', 'MA', 'Age-adjusted Rate', '9.2', 'cases per 1,000,000'),
#  (8407, '2011', 'MS', 'Age-adjusted Rate', '18.1', 'cases per 1,000,000'),
#  (8429, '2017', 'WA', 'Age-adjusted Rate', '13', 'cases per 1,000,000'),
#  (8460, '2013', 'NE', 'Age-adjusted Rate', '11', 'cases per 1,000,000'),
#  (8475, '2014', 'MO', 'Age-adjusted Rate', '13.7', 'cases per 1,000,000'),
#  (8477, '2016', 'NM', 'Age-adjusted Rate', '12.8', 'cases per 1,000,000'),
#  (8497, '2016', 'MI', 'Age-adjusted Rate', '8.6', 'cases per 1,000,000'),
#  (8508, '2011', 'OH', 'Age-adjusted Rate', '9.8', 'cases per 1,000,000'),
#  (8511, '2016', 'NV', 'Crude Rate', '12.6', 'cases per 1,000,000'),
#  (8520, '2016', 'TN', 'Age-adjusted Rate', '11.4', 'cases per 1,000,000'),
#  (8530, '2012', 'NV', 'Number', '20', None),
#  (8532, '2015', 'WA', 'Crude Rate', '12.3', 'cases per 1,000,000'),
#  (8535, '2015', 'MS', 'Age-adjusted Rate', '16', 'cases per 1,000,000'),
#  (8552, '2011', 'OK', 'Age-adjusted Rate', '11.1', 'cases per 1,000,000'),
#  (8555, '2010', 'NM', 'Number', '22', None),
#  (8589, '2014', 'NE', 'Number', '30', None),
#  (8593, '2016', 'MO', 'Crude Rate', '12', 'cases per 1,000,000'),
#  (8598, '2017', 'OR', 'Age-adjusted Rate', '12.8', 'cases per 1,000,000'),
#  (8607, '2011', 'NE', 'Crude Rate', '17.4', 'cases per 1,000,000'),
#  (8609, '2014', 'OK', 'Age-adjusted Rate', '13.6', 'cases per 1,000,000'),
#  (8615, '2010', 'MO', 'Crude Rate', '12.7', 'cases per 1,000,000'),
#  (8621, '2015', 'MN', 'Crude Rate', '11.1', 'cases per 1,000,000'),
#  (8627, '2012', 'MN', 'Age-adjusted Rate', '12', 'cases per 1,000,000'),
#  (8642, '2013', 'WV', 'Age-adjusted Rate', '13.6', 'cases per 1,000,000'),
#  (8644, '2010', 'NV', 'Number', '27', None),
#  (8650, '2013', 'LA', 'Number', '56', None),
#  (8655, '2016', 'WI', 'Age-adjusted Rate', '10', 'cases per 1,000,000'),
#  (8662, '2012', 'MO', 'Number', '75', None),
#  (8668, '2016', 'SC', 'Number', '60', None),
#  (8677, '2016', 'UT', 'Crude Rate', '11.8', 'cases per 1,000,000'),
#  (8678, '2011', 'WV', 'Crude Rate', '11.9', 'cases per 1,000,000'),
#  (8684, '2012', 'MI', 'Crude Rate', '10.8', 'cases per 1,000,000'),
#  (8689, '2016', 'TX', 'Number', '196', None),
#  (8710, '2016', 'LA', 'Crude Rate', '9', 'cases per 1,000,000'),
#  (8712, '2013', 'SC', 'Crude Rate', '12.8', 'cases per 1,000,000'),
#  (8720, '2014', 'OR', 'Number', '77', None),
#  (8724, '2010', 'WA', 'Age-adjusted Rate', '10.6', 'cases per 1,000,000'),
#  (8727, '2010', 'KY', 'Number', '44', None),
#  (8730, '2015', 'OH', 'Crude Rate', '13.7', 'cases per 1,000,000'),
#  (8754, '2011', 'SC', 'Number', '70', None),
#  (8783, '2010', 'NY', 'Crude Rate', '14.6', 'cases per 1,000,000'),
#  (8785, '2014', 'NV', 'Crude Rate', '8.8', 'cases per 1,000,000'),
#  (8797, '2014', 'PA', 'Crude Rate', '11.7', 'cases per 1,000,000'),
#  (8815, '2010', 'TN', 'Number', '67', None),
#  (8837, '2010', 'LA', 'Crude Rate', '7.9', 'cases per 1,000,000'),
#  (8861, '2015', 'SC', 'Number', '57', None),
#  (8877, '2011', 'WA', 'Age-adjusted Rate', '11.3', 'cases per 1,000,000'),
#  (8879, '2017', 'TN', 'Number', '72', None),
#  (8881, '2011', 'NC', 'Age-adjusted Rate', '9.7', 'cases per 1,000,000'),
#  (8898, '2017', 'OH', 'Age-adjusted Rate', '10.5', 'cases per 1,000,000'),
#  (8927, '2013', 'MO', 'Age-adjusted Rate', '8.3', 'cases per 1,000,000'),
#  (8930, '2013', 'TX', 'Number', '213', None),
#  (8932, '2015', 'NE', 'Number', '36', None),
#  (8964, '2013', 'NJ', 'Number', '134', None),
#  (8972, '2013', 'TN', 'Number', '62', None),
#  (8979, '2010', 'WI', 'Crude Rate', '11.1', 'cases per 1,000,000'),
#  (8984, '2012', 'UT', 'Number', '28', None),
#  (8988, '2011', 'MO', 'Crude Rate', '8', 'cases per 1,000,000'),
#  (8996, '2017', 'NE', 'Crude Rate', '12', 'cases per 1,000,000'),
#  (9005, '2015', 'MI', 'Age-adjusted Rate', '10.3', 'cases per 1,000,000'),
#  (9006, '2014', 'KY', 'Number', '35', None),
#  (9012, '2016', 'OR', 'Number', '75', None),
#  (9015, '2015', 'NV', 'Number', '24', None),
#  (9017, '2015', 'UT', 'Age-adjusted Rate', '16', 'cases per 1,000,000'),
#  (9039, '2015', 'OR', 'Crude Rate', '13.2', 'cases per 1,000,000'),
#  (9047, '2011', 'SD', 'Number', '20', None),
#  (9054, '2010', 'OH', 'Number', '151', None),
#  (9062, '2010', 'WV', 'Number', '24', None),
#  (9074, '2016', 'MA', 'Number', '86', None),
#  (9075, '2012', 'NY', 'Number', '284', None),
#  (9077, '2017', 'NJ', 'Number', '110', None),
#  (9078, '2017', 'PA', 'Crude Rate', '10.3', 'cases per 1,000,000'),
#  (9089, '2011', 'MN', 'Age-adjusted Rate', '10.1', 'cases per 1,000,000'),
#  (9093, '2017', 'KS', 'Crude Rate', '14.8', 'cases per 1,000,000'),
#  (9137, '2014', 'MN', 'Number', '66', None),
#  (9161, '2017', 'MO', 'Age-adjusted Rate', '10.1', 'cases per 1,000,000'),
#  (9164, '2016', 'WV', 'Crude Rate', '13.7', 'cases per 1,000,000'),
#  (9186, '2017', 'WI', 'Crude Rate', '10.2', 'cases per 1,000,000'),
#  (9196, '2015', 'OK', 'Crude Rate', '13.3', 'cases per 1,000,000'),
#  (9219, '2012', 'LA', 'Crude Rate', '8.7', 'cases per 1,000,000'),
#  (9223, '2013', 'KY', 'Crude Rate', '8.2', 'cases per 1,000,000'),
#  (9224, '2014', 'MA', 'Crude Rate', '11.3', 'cases per 1,000,000'),
#  (9226, '2014', 'SC', 'Age-adjusted Rate', '14.7', 'cases per 1,000,000'),
#  (9236, '2014', 'LA', 'Age-adjusted Rate', '12.4', 'cases per 1,000,000'),
#  (9239, '2014', 'MS', 'Number', '48', None),
#  (9245, '2014', 'WI', 'Crude Rate', '13.4', 'cases per 1,000,000'),
#  (9246, '2017', 'NV', 'Crude Rate', '10.7', 'cases per 1,000,000'),
#  (9256, '2012', 'OH', 'Crude Rate', '12.6', 'cases per 1,000,000'),
#  (9264, '2011', 'KY', 'Number', '33', None),
#  (9279, '2013', 'PA', 'Age-adjusted Rate', '10.5', 'cases per 1,000,000'),
#  (9286, '2014', 'NE', 'Crude Rate', '15.9', 'cases per 1,000,000'),
#  (9301, '2015', 'VA', 'Age-adjusted Rate', '10.3', 'cases per 1,000,000'),
#  (9315, '2015', 'MO', 'Crude Rate', '11.8', 'cases per 1,000,000'),
#  (9332, '2014', 'NY', 'Crude Rate', '15.3', 'cases per 1,000,000'),
#  (9344, '2017', 'TX', 'Number', '232', None),
#  (9370, '2012', 'NE', 'Age-adjusted Rate', '12.4', 'cases per 1,000,000'),
#  (9389, '2013', 'WI', 'Age-adjusted Rate', '11.1', 'cases per 1,000,000'),
#  (9391, '2010', 'NJ', 'Age-adjusted Rate', '8.1', 'cases per 1,000,000'),
#  (9393, '2017', 'LA', 'Number', '39', None),
#  (9441, '2010', 'OK', 'Age-adjusted Rate', '9', 'cases per 1,000,000'),
#  (9461, '2014', 'OH', 'Age-adjusted Rate', '9.1', 'cases per 1,000,000'),
#  (9475, '2017', 'OK', 'Age-adjusted Rate', '13.4', 'cases per 1,000,000'),
#  (9508, '2013', 'OR', 'Age-adjusted Rate', '13.5', 'cases per 1,000,000'),
#  (9510, '2015', 'NC', 'Age-adjusted Rate', '9', 'cases per 1,000,000'),
#  (9518, '2010', 'MA', 'Crude Rate', '7.6', 'cases per 1,000,000'),
#  (9522, '2016', 'WA', 'Crude Rate', '10.7', 'cases per 1,000,000'),
#  (9526, '2010', 'VA', 'Number', '69', None),
#  (9529, '2016', 'PA', 'Age-adjusted Rate', '8.2', 'cases per 1,000,000'),
#  (9530, '2010', 'TX', 'Crude Rate', '7.6', 'cases per 1,000,000'),
#  (9532, '2015', 'PA', 'Crude Rate', '12.1', 'cases per 1,000,000'),
#  (9580, '2011', 'WI', 'Crude Rate', '11.2', 'cases per 1,000,000'),
#  (9587, '2011', 'VA', 'Age-adjusted Rate', '10.8', 'cases per 1,000,000'),
#  (9589, '2012', 'MA', 'Number', '58', None),
#  (9590, '2015', 'WV', 'Crude Rate', '13.6', 'cases per 1,000,000'),
#  (9593, '2010', 'MS', 'Number', '49', None),
#  (9595, '2011', 'OR', 'Crude Rate', '11.9', 'cases per 1,000,000'),
#  (9650, '2017', 'WV', 'Age-adjusted Rate', '10.6', 'cases per 1,000,000'),
#  (9695, '2017', 'VA', 'Age-adjusted Rate', '7.5', 'cases per 1,000,000'),
#  (9701, '2016', 'NM', 'Number', '27', None),
#  (9702, '2014', 'TN', 'Age-adjusted Rate', '9.3', 'cases per 1,000,000'),
#  (9714, '2017', 'MS', 'Age-adjusted Rate', '14.3', 'cases per 1,000,000'),
#  (9721, '2011', 'UT', 'Age-adjusted Rate', '19.5', 'cases per 1,000,000'),
#  (9730, '2013', 'NV', 'Crude Rate', '9.7', 'cases per 1,000,000'),
#  (9734, '2011', 'MI', 'Age-adjusted Rate', '10.5', 'cases per 1,000,000'),
#  (9738, '2016', 'MD', 'Number', '79', None),
#  (9776, '2011', 'NV', 'Number', '20', None),
#  (9782, '2017', 'KY', 'Crude Rate', '7.2', 'cases per 1,000,000'),
#  (9805, '2014', 'WA', 'Number', '93', None),
#  (9816, '2010', 'MI', 'Crude Rate', '10.6', 'cases per 1,000,000'),
#  (9827, '2017', 'FL', 'Number', '112999', None),
#  (9830, '2013', 'NY', 'Number', '179657', None),
#  (9835, '2013', 'VT', 'Number', '314', None),
#  (9836, '2015', 'WI', 'Age-adjusted Rate', '46.3', 'cases per 10,000'),
#  (9880, '2017', 'IA', 'Crude Rate', '30.55', 'cases per 10,000'),
#  (9904, '2017', 'MN', 'Crude Rate', '32.32', 'cases per 10,000'),
#  (9950, '2010', 'HI', 'Age-adjusted Rate', '55.06', 'cases per 10,000'),
#  (9952, '2010', 'MD', 'Number', '56070', None),
#  (9981, '2016', 'NV', 'Number', '13993', None),
#  (10023, '2017', 'MD', 'Crude Rate', '56.91', 'cases per 10,000'),
#  (10044, '2015', 'MD', 'Age-adjusted Rate', '71.57', 'cases per 10,000'),
#  (10045, '2017', 'NJ', 'Number', '54208', None),
#  (10067, '2015', 'AZ', 'Crude Rate', '46.45', 'cases per 10,000'),
#  (10069, '2016', 'IA', 'Age-adjusted Rate', '33.39', 'cases per 10,000'),
#  (10071, '2014', 'KY', 'Number', '22413', None),
#  (10107, '2016', 'NC', 'Age-adjusted Rate', '52.2', 'cases per 10,000'),
#  (10113, '2016', 'KY', 'Crude Rate', '40.2', 'cases per 10,000'),
#  (10122, '2016', 'RI', 'Number', '5010', None),
#  (10157, '2014', 'HI', 'Number', '8526', None),
#  (10291, '2014', 'MD', 'Crude Rate', '77.17', 'cases per 10,000'),
#  (10299, '2016', 'VT', 'Number', '140', None),
#  (10322, '2016', 'AZ', 'Crude Rate', '42.83', 'cases per 10,000'),
#  (10386, '2015', 'AR', 'Number', '9564', None),
#  (10429, '2014', 'GA', 'Age-adjusted Rate', '65.46', 'cases per 10,000'),
#  (10474, '2010', 'CA', 'Number', '217637', None),
#  (10485, '2010', 'SC', 'Number', '24076', None),
#  (10553, '2015', 'VT', 'Crude Rate', '39.34', 'cases per 10,000'),
#  (10574, '2014', 'AZ', 'Crude Rate', '48.6', 'cases per 10,000'),
#  (10579, '2010', 'NJ', 'Crude Rate', '92.74', 'cases per 10,000'),
#  (10596, '2016', 'WI', 'Age-adjusted Rate', '41.05', 'cases per 10,000'),
#  (10604, '2017', 'KY', 'Age-adjusted Rate', '38.34', 'cases per 10,000'),
#  (10707, '2016', 'FL', 'Number', '117043', None),
#  (10713, '2010', 'NJ', 'Number', '81536', None),
#  (10737, '2013', 'WI', 'Age-adjusted Rate', '43', 'cases per 10,000'),
#  (10740, '2010', 'NY', 'Age-adjusted Rate', '117.69', 'cases per 10,000'),
#  (10745, '2010', 'IA', 'Crude Rate', '46.39', 'cases per 10,000'),
#  (10776, '2010', 'AZ', 'Crude Rate', '63.59', 'cases per 10,000'),
#  (10778, '2016', 'VT', 'Number', '2117', None),
#  (10818, '2016', 'AZ', 'Number', '29688', None),
#  (10824, '2017', 'AZ', 'Age-adjusted Rate', '42.4', 'cases per 10,000'),
#  (10832, '2013', 'VT', 'Number', '2545', None),
#  (10849, '2015', 'NJ', 'Crude Rate', '69.91', 'cases per 10,000'),
#  (10866, '2013', 'NJ', 'Number', '66250', None),
#  (10872, '2010', 'NJ', 'Age-adjusted Rate', '94.61', 'cases per 10,000'),
#  (10878, '2015', 'NE', 'Crude Rate', '31.45', 'cases per 10,000'),
#  (10920, '2014', 'MN', 'Number', '21814', None),
#  (10939, '2013', 'AZ', 'Age-adjusted Rate', '48.5', 'cases per 10,000'),
#  (10983, '2015', 'MN', 'Number', '14805', None),
#  (11008, '2017', 'WI', 'Crude Rate', '37.79', 'cases per 10,000'),
#  (11014, '2016', 'MN', 'Number', '18117', None),
#  (11019, '2015', 'KY', 'Crude Rate', '48.23', 'cases per 10,000'),
#  (11049, '2015', 'SC', 'Crude Rate', '56.11', 'cases per 10,000'),
#  (11054, '2017', 'NE', 'Age-adjusted Rate', '26.4', 'cases per 10,000'),
#  (11094, '2016', 'AR', 'Age-adjusted Rate', '41.51', 'cases per 10,000'),
#  (11129, '2014', 'RI', 'Crude Rate', '55.6', 'cases per 10,000'),
#  (11130, '2013', 'NV', 'Number', '13652', None),
#  (11198, '2016', 'NE', 'Age-adjusted Rate', '28.01', 'cases per 10,000'),
#  (11203, '2014', 'NC', 'Number', '58330', None),
#  (11230, '2013', 'NE', 'Age-adjusted Rate', '29.6', 'cases per 10,000'),
#  ...]

# %% [markdown]
# # ETL of [Air Data](https://www.epa.gov/outdoor-air-quality-data)

# %%
# final table needs to have: year, state_id, air_quality_indexes

# %%
#filtered_asthma_df['year'].unique()
# Out:
# array(['2011', '2013', '2012', '2015', '2019', '2014', '2016', '2017',
#        '2010', '2018'], dtype=object)

# %%
#res_list = []
#for year in ['2011','2012']:
#    url= f'https://aqs.epa.gov/data/api/annualData/byState?email={userID}&key={key}&param=81102,81104&bdate={year}0101&edate={year}1231&state=37'
#    r = requests.get(url)
#    print(r.status_code)
#    res_list += [r.json()]
# Out:
# 200
# 200

# %%
#air_df_list = []

#for res in res_list:
#    air_df_list += [pd.DataFrame(res['Data'])]
#air_df = pd.concat(air_df_list)
#air_df
# Out:
#    state_code county_code site_number parameter_code  poc   latitude  \
# 0          37         117        0001          81102    1  35.810660
# 1          37         123        0001          81102    1  35.263165
# 2          37         183        0014          81102    7  35.856111
# 3          37         111        0004          81102    1  35.687406
# 4          37         035        0004          81102    2  35.728889
# 5          37         035        0004          81102    1  35.728889
# 6          37         081        0013          81102    1  36.109006
# 7          37         051        0009          81102    1  35.041416
# 8          37         063        0015          81102    7  36.032955
# 9          37         119        0003          81102    2  35.251717
# 10         37         119        0003          81102    1  35.251717
# 11         37         119        0041          81102    1  35.240100
# 12         37         119        0042          81102    2  35.151283
# 13         37         119        0042          81102    1  35.151283
# 14         37         067        0022          81102    1  36.110940
# 15         37         067        0023          81102    2  36.065970
# 16         37         067        0022          81102    1  36.110940
# 17         37         067        0023          81102    2  36.065970
# 0          37         067        0022          81102    1  36.110940
# 1          37         067        0022          81102    1  36.110940
# 2          37         119        0042          81102    2  35.151283
# 3          37         119        0042          81102    1  35.151283
# 4          37         119        0041          81102    1  35.240100
# 5          37         119        0003          81102    2  35.251717
# 6          37         119        0003          81102    1  35.251717
# 7          37         063        0015          81102    7  36.032955
# 8          37         051        0009          81102    1  35.041416
# 9          37         081        0013          81102    1  36.109006
# 10         37         035        0004          81102    2  35.728889
# 11         37         035        0004          81102    1  35.728889
# 12         37         111        0004          81102    1  35.687406
# 13         37         183        0014          81102    7  35.856111
# 14         37         123        0001          81102    1  35.263165
# 15         37         117        0001          81102    1  35.810660
#
#     longitude  datum              parameter sample_duration  ...  \
# 0  -76.906300  WGS84  PM10 Total 0-10um STP         24 HOUR  ...
# 1  -79.836636  NAD83  PM10 Total 0-10um STP         24 HOUR  ...
# 2  -78.574167  WGS84  PM10 Total 0-10um STP         24 HOUR  ...
# 3  -81.993808  WGS84  PM10 Total 0-10um STP         24 HOUR  ...
# 4  -81.365556  WGS84  PM10 Total 0-10um STP         24 HOUR  ...
# 5  -81.365556  WGS84  PM10 Total 0-10um STP         24 HOUR  ...
# 6  -79.802314  NAD83  PM10 Total 0-10um STP         24 HOUR  ...
# 7  -78.953112  WGS84  PM10 Total 0-10um STP         24 HOUR  ...
# 8  -78.904037  NAD83  PM10 Total 0-10um STP         24 HOUR  ...
# 9  -80.824717  WGS84  PM10 Total 0-10um STP         24 HOUR  ...
# 10 -80.824717  WGS84  PM10 Total 0-10um STP         24 HOUR  ...
# 11 -80.785683  WGS84  PM10 Total 0-10um STP         24 HOUR  ...
# 12 -80.866983  WGS84  PM10 Total 0-10um STP         24 HOUR  ...
# 13 -80.866983  WGS84  PM10 Total 0-10um STP         24 HOUR  ...
# 14 -80.224501  WGS84  PM10 Total 0-10um STP   24-HR BLK AVG  ...
# 15 -80.258105  WGS84  PM10 Total 0-10um STP   24-HR BLK AVG  ...
# 16 -80.224501  WGS84  PM10 Total 0-10um STP          1 HOUR  ...
# 17 -80.258105  WGS84  PM10 Total 0-10um STP          1 HOUR  ...
# 0  -80.224501  WGS84  PM10 Total 0-10um STP          1 HOUR  ...
# 1  -80.224501  WGS84  PM10 Total 0-10um STP   24-HR BLK AVG  ...
# 2  -80.866983  WGS84  PM10 Total 0-10um STP         24 HOUR  ...
# 3  -80.866983  WGS84  PM10 Total 0-10um STP         24 HOUR  ...
# 4  -80.785683  WGS84  PM10 Total 0-10um STP         24 HOUR  ...
# 5  -80.824717  WGS84  PM10 Total 0-10um STP         24 HOUR  ...
# 6  -80.824717  WGS84  PM10 Total 0-10um STP         24 HOUR  ...
# 7  -78.904037  NAD83  PM10 Total 0-10um STP         24 HOUR  ...
# 8  -78.953112  WGS84  PM10 Total 0-10um STP         24 HOUR  ...
# 9  -79.802314  NAD83  PM10 Total 0-10um STP         24 HOUR  ...
# 10 -81.365556  WGS84  PM10 Total 0-10um STP         24 HOUR  ...
# 11 -81.365556  WGS84  PM10 Total 0-10um STP         24 HOUR  ...
# 12 -81.993808  WGS84  PM10 Total 0-10um STP         24 HOUR  ...
# 13 -78.574167  WGS84  PM10 Total 0-10um STP         24 HOUR  ...
# 14 -79.836636  NAD83  PM10 Total 0-10um STP         24 HOUR  ...
# 15 -76.906300  WGS84  PM10 Total 0-10um STP         24 HOUR  ...
#
#    fiftieth_percentile tenth_percentile               local_site_name  \
# 0                  9.0              9.0             Jamesville School
# 1                 12.0              6.0      Candor: EPA CASTNet Site
# 2                 14.0              7.0              Millbrook School
# 3                 14.0              6.0                   Marion Sch.
# 4                 13.0              7.0           Hickory Water Tower
# 5                 13.0              5.0           Hickory Water Tower
# 6                  9.0              5.0             Mendenhall School
# 7                 13.0              6.0           William Owen School
# 8                 14.0              8.0                 Durham Armory
# 9                 21.0              9.0              #11 Fire Station
# 10                20.0              8.0              #11 Fire Station
# 11                17.0              7.0          Garinger High School
# 12                16.0              6.0  Montclaire Elementary School
# 13                17.0              6.0  Montclaire Elementary School
# 14                13.0              6.0                 Hattie Avenue
# 15                14.0              7.0                  Peters Creek
# 16                14.0              6.0                 Hattie Avenue
# 17                13.0              5.0                  Peters Creek
# 0                 13.0              6.0                 Hattie Avenue
# 1                 12.0              7.0                 Hattie Avenue
# 2                 14.0              8.0  Montclaire Elementary School
# 3                 16.0              8.0  Montclaire Elementary School
# 4                 15.0              8.0          Garinger High School
# 5                 17.0             10.0              #11 Fire Station
# 6                 17.0             10.0              #11 Fire Station
# 7                 13.0              7.0                 Durham Armory
# 8                 15.0             10.0           William Owen School
# 9                 13.0              8.0             Mendenhall School
# 10                15.0             10.0           Hickory Water Tower
# 11                16.0             12.0           Hickory Water Tower
# 12                16.0             13.0                   Marion Sch.
# 13                13.0              8.0              Millbrook School
# 14                10.0              5.0      Candor: EPA CASTNet Site
# 15                13.0              8.0             Jamesville School
#
#                          site_address           state       county  \
# 0                   1210 Hayes Street  North Carolina       Martin
# 1                     126 PERRY DRIVE  North Carolina   Montgomery
# 2              3801 SPRING FOREST RD.  North Carolina         Wake
# 3                    676 State Street  North Carolina     McDowell
# 4                     1650 1ST STREET  North Carolina      Catawba
# 5                     1650 1ST STREET  North Carolina      Catawba
# 6                  205 WILOUGHBY BLVD  North Carolina     Guilford
# 7                     4533 RAEFORD RD  North Carolina   Cumberland
# 8                   801 STADIUM DRIVE  North Carolina       Durham
# 9   FIRE STA #11 620 WEST 28TH STREET  North Carolina  Mecklenburg
# 10  FIRE STA #11 620 WEST 28TH STREET  North Carolina  Mecklenburg
# 11                 1130 EASTWAY DRIVE  North Carolina  Mecklenburg
# 12               1935 Emerywood Drive  North Carolina  Mecklenburg
# 13               1935 Emerywood Drive  North Carolina  Mecklenburg
# 14            1300 BLK. HATTIE AVENUE  North Carolina      Forsyth
# 15           1401 CORPORATION PARKWAY  North Carolina      Forsyth
# 16            1300 BLK. HATTIE AVENUE  North Carolina      Forsyth
# 17           1401 CORPORATION PARKWAY  North Carolina      Forsyth
# 0             1300 BLK. HATTIE AVENUE  North Carolina      Forsyth
# 1             1300 BLK. HATTIE AVENUE  North Carolina      Forsyth
# 2                1935 Emerywood Drive  North Carolina  Mecklenburg
# 3                1935 Emerywood Drive  North Carolina  Mecklenburg
# 4                  1130 EASTWAY DRIVE  North Carolina  Mecklenburg
# 5   FIRE STA #11 620 WEST 28TH STREET  North Carolina  Mecklenburg
# 6   FIRE STA #11 620 WEST 28TH STREET  North Carolina  Mecklenburg
# 7                   801 STADIUM DRIVE  North Carolina       Durham
# 8                     4533 RAEFORD RD  North Carolina   Cumberland
# 9                  205 WILOUGHBY BLVD  North Carolina     Guilford
# 10                    1650 1ST STREET  North Carolina      Catawba
# 11                    1650 1ST STREET  North Carolina      Catawba
# 12                   676 State Street  North Carolina     McDowell
# 13             3801 SPRING FOREST RD.  North Carolina         Wake
# 14                    126 PERRY DRIVE  North Carolina   Montgomery
# 15                  1210 Hayes Street  North Carolina       Martin
#
#              city  cbsa_code                               cbsa  \
# 0      Jamesville       None                               None
# 1          Candor       None                               None
# 2         Raleigh      39580                        Raleigh, NC
# 3          Marion      32000                         Marion, NC
# 4         Hickory      25860       Hickory-Lenoir-Morganton, NC
# 5         Hickory      25860       Hickory-Lenoir-Morganton, NC
# 6      Greensboro      24660          Greensboro-High Point, NC
# 7    Fayetteville      22180                   Fayetteville, NC
# 8          Durham      20500             Durham-Chapel Hill, NC
# 9       Charlotte      16740  Charlotte-Concord-Gastonia, NC-SC
# 10      Charlotte      16740  Charlotte-Concord-Gastonia, NC-SC
# 11      Charlotte      16740  Charlotte-Concord-Gastonia, NC-SC
# 12      Charlotte      16740  Charlotte-Concord-Gastonia, NC-SC
# 13      Charlotte      16740  Charlotte-Concord-Gastonia, NC-SC
# 14  Winston-Salem      49180                  Winston-Salem, NC
# 15  Winston-Salem      49180                  Winston-Salem, NC
# 16  Winston-Salem      49180                  Winston-Salem, NC
# 17  Winston-Salem      49180                  Winston-Salem, NC
# 0   Winston-Salem      49180                  Winston-Salem, NC
# 1   Winston-Salem      49180                  Winston-Salem, NC
# 2       Charlotte      16740  Charlotte-Concord-Gastonia, NC-SC
# 3       Charlotte      16740  Charlotte-Concord-Gastonia, NC-SC
# 4       Charlotte      16740  Charlotte-Concord-Gastonia, NC-SC
# 5       Charlotte      16740  Charlotte-Concord-Gastonia, NC-SC
# 6       Charlotte      16740  Charlotte-Concord-Gastonia, NC-SC
# 7          Durham      20500             Durham-Chapel Hill, NC
# 8    Fayetteville      22180                   Fayetteville, NC
# 9      Greensboro      24660          Greensboro-High Point, NC
# 10        Hickory      25860       Hickory-Lenoir-Morganton, NC
# 11        Hickory      25860       Hickory-Lenoir-Morganton, NC
# 12         Marion      32000                         Marion, NC
# 13        Raleigh      39580                        Raleigh, NC
# 14         Candor       None                               None
# 15     Jamesville       None                               None
#
#     date_of_last_change
# 0            2020-05-21
# 1            2020-05-21
# 2            2020-05-21
# 3            2020-05-21
# 4            2020-05-21
# 5            2020-05-21
# 6            2020-05-21
# 7            2020-05-21
# 8            2020-05-21
# 9            2020-05-21
# 10           2020-05-21
# 11           2020-05-21
# 12           2020-05-21
# 13           2020-05-21
# 14           2020-05-21
# 15           2020-05-21
# 16           2020-05-21
# 17           2020-05-21
# 0            2020-05-21
# 1            2020-05-21
# 2            2020-05-21
# 3            2020-05-21
# 4            2020-05-21
# 5            2020-05-21
# 6            2020-05-21
# 7            2020-05-21
# 8            2020-05-21
# 9            2020-05-21
# 10           2020-05-21
# 11           2020-05-21
# 12           2020-05-21
# 13           2020-05-21
# 14           2020-05-21
# 15           2020-05-21
#
# [34 rows x 55 columns]

# %%
#air_df['parameter'].unique()
# Out:
# array(['PM10 Total 0-10um STP'], dtype=object)

# %%
#air_df.columns
# Out:
# Index(['state_code', 'county_code', 'site_number', 'parameter_code', 'poc',
#        'latitude', 'longitude', 'datum', 'parameter', 'sample_duration',
#        'pollutant_standard', 'metric_used', 'method', 'year',
#        'units_of_measure', 'event_type', 'observation_count',
#        'observation_percent', 'validity_indicator', 'valid_day_count',
#        'required_day_count', 'exceptional_data_count',
#        'null_observation_count', 'primary_exceedance_count',
#        'secondary_exceedance_count', 'certification_indicator',
#        'arithmetic_mean', 'standard_deviation', 'first_max_value',
#        'first_max_datetime', 'second_max_value', 'second_max_datetime',
#        'third_max_value', 'third_max_datetime', 'fourth_max_value',
#        'fourth_max_datetime', 'first_max_nonoverlap_value',
#        'first_max_n_o_datetime', 'second_max_nonoverlap_value',
#        'second_max_n_o_datetime', 'ninety_ninth_percentile',
#        'ninety_eighth_percentile', 'ninety_fifth_percentile',
#        'ninetieth_percentile', 'seventy_fifth_percentile',
#        'fiftieth_percentile', 'tenth_percentile', 'local_site_name',
#        'site_address', 'state', 'county', 'city', 'cbsa_code', 'cbsa',
#        'date_of_last_change'],
#       dtype='object')

# %%
#air_df['observation_percent']
# Out:
# 0       2.0
# 1      85.0
# 2      98.0
# 3      80.0
# 4      93.0
# 5      97.0
# 6      93.0
# 7     100.0
# 8      91.0
# 9      90.0
# 10     95.0
# 11     98.0
# 12     97.0
# 13     98.0
# 14     79.0
# 15     51.0
# 16     80.0
# 17     51.0
# 0      98.0
# 1      98.0
# 2      98.0
# 3      96.0
# 4      96.0
# 5      97.0
# 6      98.0
# 7      95.0
# 8     100.0
# 9      90.0
# 10     82.0
# 11     84.0
# 12     16.0
# 13     98.0
# 14     16.0
# 15    100.0
# Name: observation_percent, dtype: float64

# %%
#closing the connection to the sqlite database
conn.close()
