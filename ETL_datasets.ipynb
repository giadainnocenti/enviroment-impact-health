# %%
import glob
import pandas as pd
import sqlite3
from pymongo import MongoClient
from sodapy import Socrata
import requests
from math import ceil
import glob

# %%
#connecting to the sqlite database
conn = sqlite3.connect('health_air.db')
#connecting to the MongoDB Database
mongo_client = MongoClient()
#creating the MongoDB
mydb = mongo_client['health_air_mongo']

# %%
#function to add a table to the database
def add_table_to_db(table_name, df, connection_db):
    cur = conn.cursor()
    df.to_sql(name=table_name, if_exists='replace', con=conn)
    return(cur.execute(f"""SELECT * FROM {table_name};""").fetchall())

# %%
def add_collection_to_mongo (collection_name, df, mongo_db_conn = mydb):
    mongo_db_conn[collection_name].insert_many(df.to_dict('records'))
    return print(f'{collection_name} stored in the MongoDB database named {mydb}')

# %% [markdown]
# # ETL of [Asthma data](https://chronicdata.cdc.gov/Chronic-Disease-Indicators/U-S-Chronic-Disease-Indicators-Asthma/us8e-ubyj)

# %%
# Instruction from the CDC website to extract data
# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("chronicdata.cdc.gov", None)

# Return as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get_all("us8e-ubyj")

# Convert to pandas DataFrame
asthma_df = pd.DataFrame.from_records(results)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
asthma_df
# Out:
#       yearstart yearend locationabbr locationdesc datasource   topic  \
# 0          2012    2012           AL      Alabama       NVSS  Asthma
# 1          2014    2014           AL      Alabama       NVSS  Asthma
# 2          2011    2011           AZ      Arizona       NVSS  Asthma
# 3          2015    2015           CT  Connecticut       NVSS  Asthma
# 4          2011    2011           FL      Florida       NVSS  Asthma
# ...         ...     ...          ...          ...        ...     ...
# 64714      2011    2011           WI    Wisconsin      BRFSS  Asthma
# 64715      2016    2016           TX        Texas      BRFSS  Asthma
# 64716      2019    2019           WI    Wisconsin      BRFSS  Asthma
# 64717      2014    2014           PR  Puerto Rico      BRFSS  Asthma
# 64718      2017    2017           WI    Wisconsin      BRFSS  Asthma
#
#                                                 question  \
# 0                                  Asthma mortality rate
# 1                                  Asthma mortality rate
# 2                                  Asthma mortality rate
# 3                                  Asthma mortality rate
# 4                                  Asthma mortality rate
# ...                                                  ...
# 64714  Pneumococcal vaccination among noninstitutiona...
# 64715  Pneumococcal vaccination among noninstitutiona...
# 64716  Pneumococcal vaccination among noninstitutiona...
# 64717  Pneumococcal vaccination among noninstitutiona...
# 64718  Pneumococcal vaccination among noninstitutiona...
#
#                  datavaluetype datavalue datavaluealt  ... topicid questionid  \
# 0                       Number        37           37  ...     AST     AST4_1
# 1                       Number        22           22  ...     AST     AST4_1
# 2                       Number        29           29  ...     AST     AST4_1
# 3                       Number        34           34  ...     AST     AST4_1
# 4                       Number        54           54  ...     AST     AST4_1
# ...                        ...       ...          ...  ...     ...        ...
# 64714  Age-adjusted Prevalence       NaN          NaN  ...     AST     AST6_2
# 64715  Age-adjusted Prevalence       NaN          NaN  ...     AST     AST6_2
# 64716  Age-adjusted Prevalence       NaN          NaN  ...     AST     AST6_2
# 64717         Crude Prevalence       NaN          NaN  ...     AST     AST6_2
# 64718  Age-adjusted Prevalence       NaN          NaN  ...     AST     AST6_2
#
#       datavaluetypeid stratificationcategoryid1 stratificationid1  \
# 0                NMBR                    GENDER              GENF
# 1                NMBR                    GENDER              GENM
# 2                NMBR                    GENDER              GENM
# 3                NMBR                    GENDER              GENF
# 4                NMBR                    GENDER              GENM
# ...               ...                       ...               ...
# 64714      AGEADJPREV                    GENDER              GENM
# 64715      AGEADJPREV                      RACE               MRC
# 64716      AGEADJPREV                      RACE               OTH
# 64717         CRDPREV                    GENDER              GENM
# 64718      AGEADJPREV                      RACE               BLK
#
#       datavalueunit lowconfidencelimit highconfidencelimit  \
# 0               NaN                NaN                 NaN
# 1               NaN                NaN                 NaN
# 2               NaN                NaN                 NaN
# 3               NaN                NaN                 NaN
# 4               NaN                NaN                 NaN
# ...             ...                ...                 ...
# 64714             %                NaN                 NaN
# 64715             %                NaN                 NaN
# 64716             %                NaN                 NaN
# 64717             %                NaN                 NaN
# 64718             %                NaN                 NaN
#
#       datavaluefootnotesymbol  \
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ...                       ...
# 64714                    ****
# 64715                    ****
# 64716                    ****
# 64717                    ****
# 64718                    ****
#
#                                        datavaluefootnote
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 64714  Sample size of denominator and/or age group fo...
# 64715  Sample size of denominator and/or age group fo...
# 64716  Sample size of denominator and/or age group fo...
# 64717  Sample size of denominator and/or age group fo...
# 64718  Sample size of denominator and/or age group fo...
#
# [64719 rows x 23 columns]

# %%
#printing the names of the dataframe columns
asthma_df.columns
# Out:
# Index(['yearstart', 'yearend', 'locationabbr', 'locationdesc', 'datasource',
#        'topic', 'question', 'datavaluetype', 'datavalue', 'datavaluealt',
#        'stratificationcategory1', 'stratification1', 'locationid', 'topicid',
#        'questionid', 'datavaluetypeid', 'stratificationcategoryid1',
#        'stratificationid1', 'datavalueunit', 'lowconfidencelimit',
#        'highconfidencelimit', 'datavaluefootnotesymbol', 'datavaluefootnote'],
#       dtype='object')

# %%
# printing the question the data are answering
asthma_df['question'].unique()
# Out:
# array(['Asthma mortality rate',
#        'Emergency department visit rate for asthma',
#        'Hospitalizations for asthma',
#        'Current asthma prevalence among adults aged >= 18 years',
#        'Asthma prevalence among women aged 18-44 years',
#        'Influenza vaccination among noninstitutionalized adults aged 18-64 years with asthma',
#        'Influenza vaccination among noninstitutionalized adults aged >= 65 years with asthma',
#        'Pneumococcal vaccination among noninstitutionalized adults aged 18-64 years with asthma',
#        'Pneumococcal vaccination among noninstitutionalized adults aged >= 65 years with asthma'],
#       dtype=object)

# %%
#list containing the questions of interest for our project
questions_OI = ['Current asthma prevalence among adults aged >= 18 years']

# %%
#retrieving the unique ID per question so that we address eventual spelling mistakes
questionids_list=[]
for question in questions_OI:
    questionids_list += list(asthma_df[asthma_df['question']==question]['questionid'].unique())
print(questionids_list)
# Out:
# ['AST1_1']

# %%
# filtering the dataset for the questions of interest
filtered_asthma_df = asthma_df[asthma_df['questionid'].isin(questionids_list)]
filtered_asthma_df
# Out:
#       yearstart yearend locationabbr   locationdesc datasource   topic  \
# 19         2017    2017           IA           Iowa      BRFSS  Asthma
# 20         2016    2016           MO       Missouri      BRFSS  Asthma
# 22648      2016    2016           AZ        Arizona      BRFSS  Asthma
# 22649      2019    2019           AL        Alabama      BRFSS  Asthma
# 22650      2012    2012           CO       Colorado      BRFSS  Asthma
# ...         ...     ...          ...            ...        ...     ...
# 37543      2016    2016           NM     New Mexico      BRFSS  Asthma
# 37544      2011    2011           RI   Rhode Island      BRFSS  Asthma
# 37547      2019    2019           ID          Idaho      BRFSS  Asthma
# 37550      2014    2014           MO       Missouri      BRFSS  Asthma
# 37551      2013    2013           WV  West Virginia      BRFSS  Asthma
#
#                                                 question  \
# 19     Current asthma prevalence among adults aged >=...
# 20     Current asthma prevalence among adults aged >=...
# 22648  Current asthma prevalence among adults aged >=...
# 22649  Current asthma prevalence among adults aged >=...
# 22650  Current asthma prevalence among adults aged >=...
# ...                                                  ...
# 37543  Current asthma prevalence among adults aged >=...
# 37544  Current asthma prevalence among adults aged >=...
# 37547  Current asthma prevalence among adults aged >=...
# 37550  Current asthma prevalence among adults aged >=...
# 37551  Current asthma prevalence among adults aged >=...
#
#                  datavaluetype datavalue datavaluealt  ... topicid questionid  \
# 19            Crude Prevalence        12           12  ...     AST     AST1_1
# 20            Crude Prevalence         7            7  ...     AST     AST1_1
# 22648         Crude Prevalence       6.7          6.7  ...     AST     AST1_1
# 22649         Crude Prevalence       9.5          9.5  ...     AST     AST1_1
# 22650         Crude Prevalence       7.1          7.1  ...     AST     AST1_1
# ...                        ...       ...          ...  ...     ...        ...
# 37543         Crude Prevalence      11.4         11.4  ...     AST     AST1_1
# 37544  Age-adjusted Prevalence       NaN          NaN  ...     AST     AST1_1
# 37547  Age-adjusted Prevalence       7.9          7.9  ...     AST     AST1_1
# 37550         Crude Prevalence       9.7          9.7  ...     AST     AST1_1
# 37551         Crude Prevalence         9            9  ...     AST     AST1_1
#
#       datavaluetypeid stratificationcategoryid1 stratificationid1  \
# 19            CRDPREV                    GENDER              GENF
# 20            CRDPREV                    GENDER              GENM
# 22648         CRDPREV                      RACE               HIS
# 22649         CRDPREV                   OVERALL               OVR
# 22650         CRDPREV                    GENDER              GENM
# ...               ...                       ...               ...
# 37543         CRDPREV                      RACE               WHT
# 37544      AGEADJPREV                      RACE               MRC
# 37547      AGEADJPREV                    GENDER              GENM
# 37550         CRDPREV                   OVERALL               OVR
# 37551         CRDPREV                   OVERALL               OVR
#
#       datavalueunit lowconfidencelimit highconfidencelimit  \
# 19                %               10.7                13.3
# 20                %                5.8                 8.5
# 22648             %                  5                   9
# 22649             %                8.6                10.5
# 22650             %                6.2                 8.1
# ...             ...                ...                 ...
# 37543             %                9.9                13.2
# 37544             %                NaN                 NaN
# 37547             %                6.4                 9.7
# 37550             %                8.7                10.8
# 37551             %                8.2                 9.9
#
#       datavaluefootnotesymbol  \
# 19                        NaN
# 20                        NaN
# 22648                     NaN
# 22649                     NaN
# 22650                     NaN
# ...                       ...
# 37543                     NaN
# 37544                    ****
# 37547                     NaN
# 37550                     NaN
# 37551                     NaN
#
#                                        datavaluefootnote
# 19                                                   NaN
# 20                                                   NaN
# 22648                                                NaN
# 22649                                                NaN
# 22650                                                NaN
# ...                                                  ...
# 37543                                                NaN
# 37544  Sample size of denominator and/or age group fo...
# 37547                                                NaN
# 37550                                                NaN
# 37551                                                NaN
#
# [7831 rows x 23 columns]

# %%
#checking if column 'yearstart' and 'yearend' are the same
print(f"Are the columns datavalue and datavaluealt end the same?\n{filtered_asthma_df['datavalue'].equals(filtered_asthma_df['datavaluealt'])}")
print(f"Are the columns yearstart and year end the same?\n{filtered_asthma_df['yearstart'].equals(filtered_asthma_df['yearend'])}")
#if these columns are the same drop one of the duplicates and other not useful columns
if filtered_asthma_df['yearstart'].equals(filtered_asthma_df['yearend']):
    columns_to_drop = ['yearend',\
                        'topic',\
                        'datavaluealt',\
                        'topicid',\
                        'datavaluetypeid',\
                        'stratificationcategoryid1',\
                        'stratificationid1',\
                        'lowconfidencelimit',\
                       'highconfidencelimit',\
                       'datavaluefootnotesymbol',\
                      'datavaluefootnote']
    filtered_asthma_df=filtered_asthma_df.drop(columns=columns_to_drop)
    print(f"The following columns {columns_to_drop} were dropped")
# Out:
# Are the columns datavalue and datavaluealt end the same?
# True
# Are the columns yearstart and year end the same?
# True
# The following columns ['yearend', 'topic', 'datavaluealt', 'topicid', 'datavaluetypeid', 'stratificationcategoryid1', 'stratificationid1', 'lowconfidencelimit', 'highconfidencelimit', 'datavaluefootnotesymbol', 'datavaluefootnote'] were dropped

# %%
#renaming some columns
filtered_asthma_df=filtered_asthma_df.rename(columns={"yearstart": "year","locationabbr":"state_id","locationdesc":"state"})

# %%
#checking for missing data
filtered_asthma_df.isnull().sum()
# Out:
# year                          0
# state_id                      0
# state                         0
# datasource                    0
# question                      0
# datavaluetype                 0
# datavalue                  1602
# stratificationcategory1       0
# stratification1               0
# locationid                    0
# questionid                    0
# datavalueunit                 0
# dtype: int64

# %%
# removing missing data values
filtered_asthma_df=filtered_asthma_df[filtered_asthma_df['datavalue'].isna()==False]
filtered_asthma_df
# Out:
#        year state_id          state datasource  \
# 19     2017       IA           Iowa      BRFSS
# 20     2016       MO       Missouri      BRFSS
# 22648  2016       AZ        Arizona      BRFSS
# 22649  2019       AL        Alabama      BRFSS
# 22650  2012       CO       Colorado      BRFSS
# ...     ...      ...            ...        ...
# 37541  2012       ME          Maine      BRFSS
# 37543  2016       NM     New Mexico      BRFSS
# 37547  2019       ID          Idaho      BRFSS
# 37550  2014       MO       Missouri      BRFSS
# 37551  2013       WV  West Virginia      BRFSS
#
#                                                 question  \
# 19     Current asthma prevalence among adults aged >=...
# 20     Current asthma prevalence among adults aged >=...
# 22648  Current asthma prevalence among adults aged >=...
# 22649  Current asthma prevalence among adults aged >=...
# 22650  Current asthma prevalence among adults aged >=...
# ...                                                  ...
# 37541  Current asthma prevalence among adults aged >=...
# 37543  Current asthma prevalence among adults aged >=...
# 37547  Current asthma prevalence among adults aged >=...
# 37550  Current asthma prevalence among adults aged >=...
# 37551  Current asthma prevalence among adults aged >=...
#
#                  datavaluetype datavalue stratificationcategory1  \
# 19            Crude Prevalence        12                  Gender
# 20            Crude Prevalence         7                  Gender
# 22648         Crude Prevalence       6.7          Race/Ethnicity
# 22649         Crude Prevalence       9.5                 Overall
# 22650         Crude Prevalence       7.1                  Gender
# ...                        ...       ...                     ...
# 37541  Age-adjusted Prevalence      17.1          Race/Ethnicity
# 37543         Crude Prevalence      11.4          Race/Ethnicity
# 37547  Age-adjusted Prevalence       7.9                  Gender
# 37550         Crude Prevalence       9.7                 Overall
# 37551         Crude Prevalence         9                 Overall
#
#                  stratification1 locationid questionid datavalueunit
# 19                        Female         19     AST1_1             %
# 20                          Male         29     AST1_1             %
# 22648                   Hispanic          4     AST1_1             %
# 22649                    Overall          1     AST1_1             %
# 22650                       Male          8     AST1_1             %
# ...                          ...        ...        ...           ...
# 37541  Multiracial, non-Hispanic         23     AST1_1             %
# 37543        White, non-Hispanic         35     AST1_1             %
# 37547                       Male         16     AST1_1             %
# 37550                    Overall         29     AST1_1             %
# 37551                    Overall         54     AST1_1             %
#
# [6229 rows x 12 columns]

# %%
# checking that all the missing data value were correctly removed
filtered_asthma_df.isnull().sum()
# Out:
# year                       0
# state_id                   0
# state                      0
# datasource                 0
# question                   0
# datavaluetype              0
# datavalue                  0
# stratificationcategory1    0
# stratification1            0
# locationid                 0
# questionid                 0
# datavalueunit              0
# dtype: int64

# %%
filtered_asthma_df['question'].unique()
# Out:
# array(['Current asthma prevalence among adults aged >= 18 years'],
#       dtype=object)

# %%
# drop territories (PR, GU, VI) and nation-wide data (US)
state_to_drop = ['PR','GU','US','VI']
filtered_asthma_df = filtered_asthma_df[~filtered_asthma_df['state_id'].isin(state_to_drop)]

filtered_asthma_df
# Out:
#        year state_id          state datasource  \
# 19     2017       IA           Iowa      BRFSS
# 20     2016       MO       Missouri      BRFSS
# 22648  2016       AZ        Arizona      BRFSS
# 22649  2019       AL        Alabama      BRFSS
# 22650  2012       CO       Colorado      BRFSS
# ...     ...      ...            ...        ...
# 37541  2012       ME          Maine      BRFSS
# 37543  2016       NM     New Mexico      BRFSS
# 37547  2019       ID          Idaho      BRFSS
# 37550  2014       MO       Missouri      BRFSS
# 37551  2013       WV  West Virginia      BRFSS
#
#                                                 question  \
# 19     Current asthma prevalence among adults aged >=...
# 20     Current asthma prevalence among adults aged >=...
# 22648  Current asthma prevalence among adults aged >=...
# 22649  Current asthma prevalence among adults aged >=...
# 22650  Current asthma prevalence among adults aged >=...
# ...                                                  ...
# 37541  Current asthma prevalence among adults aged >=...
# 37543  Current asthma prevalence among adults aged >=...
# 37547  Current asthma prevalence among adults aged >=...
# 37550  Current asthma prevalence among adults aged >=...
# 37551  Current asthma prevalence among adults aged >=...
#
#                  datavaluetype datavalue stratificationcategory1  \
# 19            Crude Prevalence        12                  Gender
# 20            Crude Prevalence         7                  Gender
# 22648         Crude Prevalence       6.7          Race/Ethnicity
# 22649         Crude Prevalence       9.5                 Overall
# 22650         Crude Prevalence       7.1                  Gender
# ...                        ...       ...                     ...
# 37541  Age-adjusted Prevalence      17.1          Race/Ethnicity
# 37543         Crude Prevalence      11.4          Race/Ethnicity
# 37547  Age-adjusted Prevalence       7.9                  Gender
# 37550         Crude Prevalence       9.7                 Overall
# 37551         Crude Prevalence         9                 Overall
#
#                  stratification1 locationid questionid datavalueunit
# 19                        Female         19     AST1_1             %
# 20                          Male         29     AST1_1             %
# 22648                   Hispanic          4     AST1_1             %
# 22649                    Overall          1     AST1_1             %
# 22650                       Male          8     AST1_1             %
# ...                          ...        ...        ...           ...
# 37541  Multiracial, non-Hispanic         23     AST1_1             %
# 37543        White, non-Hispanic         35     AST1_1             %
# 37547                       Male         16     AST1_1             %
# 37550                    Overall         29     AST1_1             %
# 37551                    Overall         54     AST1_1             %
#
# [6012 rows x 12 columns]

# %%
#checking for duplicates
filtered_asthma_df=filtered_asthma_df.drop_duplicates()
filtered_asthma_df
# Out:
#        year state_id          state datasource  \
# 19     2017       IA           Iowa      BRFSS
# 20     2016       MO       Missouri      BRFSS
# 22648  2016       AZ        Arizona      BRFSS
# 22649  2019       AL        Alabama      BRFSS
# 22650  2012       CO       Colorado      BRFSS
# ...     ...      ...            ...        ...
# 37541  2012       ME          Maine      BRFSS
# 37543  2016       NM     New Mexico      BRFSS
# 37547  2019       ID          Idaho      BRFSS
# 37550  2014       MO       Missouri      BRFSS
# 37551  2013       WV  West Virginia      BRFSS
#
#                                                 question  \
# 19     Current asthma prevalence among adults aged >=...
# 20     Current asthma prevalence among adults aged >=...
# 22648  Current asthma prevalence among adults aged >=...
# 22649  Current asthma prevalence among adults aged >=...
# 22650  Current asthma prevalence among adults aged >=...
# ...                                                  ...
# 37541  Current asthma prevalence among adults aged >=...
# 37543  Current asthma prevalence among adults aged >=...
# 37547  Current asthma prevalence among adults aged >=...
# 37550  Current asthma prevalence among adults aged >=...
# 37551  Current asthma prevalence among adults aged >=...
#
#                  datavaluetype datavalue stratificationcategory1  \
# 19            Crude Prevalence        12                  Gender
# 20            Crude Prevalence         7                  Gender
# 22648         Crude Prevalence       6.7          Race/Ethnicity
# 22649         Crude Prevalence       9.5                 Overall
# 22650         Crude Prevalence       7.1                  Gender
# ...                        ...       ...                     ...
# 37541  Age-adjusted Prevalence      17.1          Race/Ethnicity
# 37543         Crude Prevalence      11.4          Race/Ethnicity
# 37547  Age-adjusted Prevalence       7.9                  Gender
# 37550         Crude Prevalence       9.7                 Overall
# 37551         Crude Prevalence         9                 Overall
#
#                  stratification1 locationid questionid datavalueunit
# 19                        Female         19     AST1_1             %
# 20                          Male         29     AST1_1             %
# 22648                   Hispanic          4     AST1_1             %
# 22649                    Overall          1     AST1_1             %
# 22650                       Male          8     AST1_1             %
# ...                          ...        ...        ...           ...
# 37541  Multiracial, non-Hispanic         23     AST1_1             %
# 37543        White, non-Hispanic         35     AST1_1             %
# 37547                       Male         16     AST1_1             %
# 37550                    Overall         29     AST1_1             %
# 37551                    Overall         54     AST1_1             %
#
# [6010 rows x 12 columns]

# %%
#checking that there isn't more than one data value entry for the same year and state.
duplicateRowsDF = filtered_asthma_df[filtered_asthma_df.duplicated(subset=['year','state_id','state','datasource','question','datavaluetype','datavaluetype','stratificationcategory1','stratification1','locationid','questionid','datavalueunit'], keep=False)]
duplicateRowsDF
# Out:
# Empty DataFrame
# Columns: [year, state_id, state, datasource, question, datavaluetype, datavalue, stratificationcategory1, stratification1, locationid, questionid, datavalueunit]
# Index: []

# %%
#keeping only the Overall values
filtered_asthma_df = filtered_asthma_df[filtered_asthma_df['stratificationcategory1'] == 'Overall']
filtered_asthma_df
# Out:
#        year state_id           state datasource  \
# 22649  2019       AL         Alabama      BRFSS
# 22673  2012       FL         Florida      BRFSS
# 22676  2019       OH            Ohio      BRFSS
# 22681  2011       VT         Vermont      BRFSS
# 22697  2014       OK        Oklahoma      BRFSS
# ...     ...      ...             ...        ...
# 37440  2011       WV   West Virginia      BRFSS
# 37524  2013       ID           Idaho      BRFSS
# 37536  2019       NC  North Carolina      BRFSS
# 37550  2014       MO        Missouri      BRFSS
# 37551  2013       WV   West Virginia      BRFSS
#
#                                                 question  \
# 22649  Current asthma prevalence among adults aged >=...
# 22673  Current asthma prevalence among adults aged >=...
# 22676  Current asthma prevalence among adults aged >=...
# 22681  Current asthma prevalence among adults aged >=...
# 22697  Current asthma prevalence among adults aged >=...
# ...                                                  ...
# 37440  Current asthma prevalence among adults aged >=...
# 37524  Current asthma prevalence among adults aged >=...
# 37536  Current asthma prevalence among adults aged >=...
# 37550  Current asthma prevalence among adults aged >=...
# 37551  Current asthma prevalence among adults aged >=...
#
#                  datavaluetype datavalue stratificationcategory1  \
# 22649         Crude Prevalence       9.5                 Overall
# 22673         Crude Prevalence       8.2                 Overall
# 22676         Crude Prevalence      11.1                 Overall
# 22681         Crude Prevalence      11.1                 Overall
# 22697         Crude Prevalence       9.7                 Overall
# ...                        ...       ...                     ...
# 37440         Crude Prevalence       9.2                 Overall
# 37524  Age-adjusted Prevalence       8.7                 Overall
# 37536  Age-adjusted Prevalence       8.2                 Overall
# 37550         Crude Prevalence       9.7                 Overall
# 37551         Crude Prevalence         9                 Overall
#
#       stratification1 locationid questionid datavalueunit
# 22649         Overall          1     AST1_1             %
# 22673         Overall         12     AST1_1             %
# 22676         Overall         39     AST1_1             %
# 22681         Overall         50     AST1_1             %
# 22697         Overall         40     AST1_1             %
# ...               ...        ...        ...           ...
# 37440         Overall         54     AST1_1             %
# 37524         Overall         16     AST1_1             %
# 37536         Overall         37     AST1_1             %
# 37550         Overall         29     AST1_1             %
# 37551         Overall         54     AST1_1             %
#
# [915 rows x 12 columns]

# %%
# final dropping of unnecessary columns
filtered_asthma_df=filtered_asthma_df.drop(columns=['state',\
                                                    'datasource',\
                                                    'stratificationcategory1',\
                                                    'stratification1',\
                                                    'locationid',\
                                                    'questionid'])
filtered_asthma_df
# Out:
#        year state_id                                           question  \
# 22649  2019       AL  Current asthma prevalence among adults aged >=...
# 22673  2012       FL  Current asthma prevalence among adults aged >=...
# 22676  2019       OH  Current asthma prevalence among adults aged >=...
# 22681  2011       VT  Current asthma prevalence among adults aged >=...
# 22697  2014       OK  Current asthma prevalence among adults aged >=...
# ...     ...      ...                                                ...
# 37440  2011       WV  Current asthma prevalence among adults aged >=...
# 37524  2013       ID  Current asthma prevalence among adults aged >=...
# 37536  2019       NC  Current asthma prevalence among adults aged >=...
# 37550  2014       MO  Current asthma prevalence among adults aged >=...
# 37551  2013       WV  Current asthma prevalence among adults aged >=...
#
#                  datavaluetype datavalue datavalueunit
# 22649         Crude Prevalence       9.5             %
# 22673         Crude Prevalence       8.2             %
# 22676         Crude Prevalence      11.1             %
# 22681         Crude Prevalence      11.1             %
# 22697         Crude Prevalence       9.7             %
# ...                        ...       ...           ...
# 37440         Crude Prevalence       9.2             %
# 37524  Age-adjusted Prevalence       8.7             %
# 37536  Age-adjusted Prevalence       8.2             %
# 37550         Crude Prevalence       9.7             %
# 37551         Crude Prevalence         9             %
#
# [915 rows x 6 columns]

# %%
# adding collection about asthma to MongoDB
add_collection_to_mongo('asthma',filtered_asthma_df)
# Out:
# asthma stored in the MongoDB database named Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'health_air_mongo')

# %%
# adding the asthma table to the database and controlling that there are data recorded.
add_table_to_db('asthma',filtered_asthma_df, conn)
# Out:
# [(22649,
#   '2019',
#   'AL',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '9.5',
#   '%'),
#  (22673,
#   '2012',
#   'FL',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '8.2',
#   '%'),
#  (22676,
#   '2019',
#   'OH',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '11.1',
#   '%'),
#  (22681,
#   '2011',
#   'VT',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '11.1',
#   '%'),
#  (22697,
#   '2014',
#   'OK',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '9.7',
#   '%'),
#  (22701,
#   '2017',
#   'ME',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '11.2',
#   '%'),
#  (22703,
#   '2011',
#   'TX',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '7.4',
#   '%'),
#  (22727,
#   '2016',
#   'AK',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '8.8',
#   '%'),
#  (22732,
#   '2011',
#   'AL',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '8',
#   '%'),
#  (22743,
#   '2013',
#   'AL',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '8.5',
#   '%'),
#  (22837,
#   '2015',
#   'AL',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '9.9',
#   '%'),
#  (22847,
#   '2019',
#   'CA',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '7.8',
#   '%'),
#  (22860,
#   '2013',
#   'AK',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '9.3',
#   '%'),
#  (22879,
#   '2015',
#   'AK',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '9.2',
#   '%'),
#  (22888,
#   '2019',
#   'AL',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '9.4',
#   '%'),
#  (22889,
#   '2011',
#   'AZ',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '9.7',
#   '%'),
#  (22895,
#   '2012',
#   'AK',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '9.1',
#   '%'),
#  (22903,
#   '2014',
#   'AK',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '8.2',
#   '%'),
#  (22908,
#   '2017',
#   'CA',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '7.9',
#   '%'),
#  (22912,
#   '2013',
#   'AZ',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '8.9',
#   '%'),
#  (22943,
#   '2011',
#   'CT',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '10.1',
#   '%'),
#  (22947,
#   '2018',
#   'AK',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '9.2',
#   '%'),
#  (22966,
#   '2015',
#   'AL',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '9.9',
#   '%'),
#  (22972,
#   '2018',
#   'AR',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '9.8',
#   '%'),
#  (22988,
#   '2012',
#   'AR',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '8.8',
#   '%'),
#  (23006,
#   '2013',
#   'CA',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '8.7',
#   '%'),
#  (23010,
#   '2011',
#   'CA',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '8.4',
#   '%'),
#  (23025,
#   '2017',
#   'AL',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '10.9',
#   '%'),
#  (23028,
#   '2017',
#   'AZ',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '9.8',
#   '%'),
#  (23029,
#   '2016',
#   'AL',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '9.7',
#   '%'),
#  (23032,
#   '2014',
#   'AL',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '9.5',
#   '%'),
#  (23038,
#   '2012',
#   'AL',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '8.6',
#   '%'),
#  (23041,
#   '2019',
#   'AZ',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '9.7',
#   '%'),
#  (23048,
#   '2013',
#   'AL',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '8.5',
#   '%'),
#  (23053,
#   '2016',
#   'AR',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '8.5',
#   '%'),
#  (23067,
#   '2011',
#   'AL',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '8',
#   '%'),
#  (23071,
#   '2017',
#   'CO',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '9.3',
#   '%'),
#  (23101,
#   '2011',
#   'CT',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '9.9',
#   '%'),
#  (23113,
#   '2014',
#   'AK',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '8.1',
#   '%'),
#  (23117,
#   '2019',
#   'CO',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '9.7',
#   '%'),
#  (23123,
#   '2015',
#   'CO',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '9.1',
#   '%'),
#  (23144,
#   '2015',
#   'AZ',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '9.3',
#   '%'),
#  (23146,
#   '2017',
#   'AL',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '10.9',
#   '%'),
#  (23155,
#   '2014',
#   'AR',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '8.8',
#   '%'),
#  (23157,
#   '2013',
#   'CO',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '8.7',
#   '%'),
#  (23161,
#   '2012',
#   'AK',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '9',
#   '%'),
#  (23176,
#   '2012',
#   'CO',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '8.9',
#   '%'),
#  (23177,
#   '2015',
#   'AR',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '10.1',
#   '%'),
#  (23185,
#   '2011',
#   'CA',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '8.4',
#   '%'),
#  (23188,
#   '2013',
#   'AR',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '8.3',
#   '%'),
#  (23204,
#   '2014',
#   'AL',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '9.5',
#   '%'),
#  (23210,
#   '2017',
#   'AZ',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '9.7',
#   '%'),
#  (23212,
#   '2016',
#   'AL',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '9.8',
#   '%'),
#  (23220,
#   '2017',
#   'AR',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '9.6',
#   '%'),
#  (23227,
#   '2011',
#   'AR',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '9.5',
#   '%'),
#  (23239,
#   '2012',
#   'AL',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '8.5',
#   '%'),
#  (23241,
#   '2016',
#   'AZ',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '9.4',
#   '%'),
#  (23243,
#   '2013',
#   'CA',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '8.7',
#   '%'),
#  (23245,
#   '2019',
#   'AZ',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '9.8',
#   '%'),
#  (23253,
#   '2012',
#   'AR',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '8.7',
#   '%'),
#  (23261,
#   '2012',
#   'CA',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '8.8',
#   '%'),
#  (23262,
#   '2018',
#   'AL',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '10.4',
#   '%'),
#  (23265,
#   '2018',
#   'AZ',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '10',
#   '%'),
#  (23279,
#   '2016',
#   'AR',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '8.5',
#   '%'),
#  (23280,
#   '2018',
#   'AR',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '9.8',
#   '%'),
#  (23282,
#   '2019',
#   'AR',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '9.3',
#   '%'),
#  (23289,
#   '2016',
#   'CA',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '7.7',
#   '%'),
#  (23297,
#   '2014',
#   'CA',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '7.7',
#   '%'),
#  (23301,
#   '2017',
#   'AK',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '8.4',
#   '%'),
#  (23302,
#   '2013',
#   'CO',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '8.7',
#   '%'),
#  (23306,
#   '2018',
#   'CO',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '9.2',
#   '%'),
#  (23308,
#   '2018',
#   'CA',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '8.5',
#   '%'),
#  (23310,
#   '2012',
#   'AZ',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '8.7',
#   '%'),
#  (23315,
#   '2014',
#   'AZ',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '9.7',
#   '%'),
#  (23317,
#   '2015',
#   'AZ',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '9.3',
#   '%'),
#  (23326,
#   '2014',
#   'AR',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '8.7',
#   '%'),
#  (23332,
#   '2019',
#   'AK',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '9.7',
#   '%'),
#  (23345,
#   '2015',
#   'CO',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '9',
#   '%'),
#  (23370,
#   '2011',
#   'CO',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '8.3',
#   '%'),
#  (23372,
#   '2019',
#   'CO',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '9.7',
#   '%'),
#  (23375,
#   '2014',
#   'CO',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '8.3',
#   '%'),
#  (23380,
#   '2017',
#   'CO',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '9.3',
#   '%'),
#  (23383,
#   '2016',
#   'CO',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '8.8',
#   '%'),
#  (23402,
#   '2018',
#   'AZ',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '10',
#   '%'),
#  (23408,
#   '2011',
#   'AK',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '8.2',
#   '%'),
#  (23410,
#   '2016',
#   'AZ',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '9.3',
#   '%'),
#  (23420,
#   '2012',
#   'CA',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '8.8',
#   '%'),
#  (23426,
#   '2011',
#   'AR',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '9.5',
#   '%'),
#  (23429,
#   '2018',
#   'AL',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '10.5',
#   '%'),
#  (23435,
#   '2015',
#   'CA',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '7.7',
#   '%'),
#  (23454,
#   '2015',
#   'AR',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '10',
#   '%'),
#  (23460,
#   '2017',
#   'AR',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '9.7',
#   '%'),
#  (23469,
#   '2013',
#   'AR',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '8.2',
#   '%'),
#  (23481,
#   '2012',
#   'CO',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '8.9',
#   '%'),
#  (23482,
#   '2016',
#   'AK',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '9',
#   '%'),
#  (23497,
#   '2011',
#   'AK',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '8.5',
#   '%'),
#  (23499,
#   '2016',
#   'CO',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '8.8',
#   '%'),
#  (23516,
#   '2011',
#   'CO',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '8.3',
#   '%'),
#  (23521,
#   '2013',
#   'AZ',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '8.9',
#   '%'),
#  (23528,
#   '2015',
#   'CA',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '7.6',
#   '%'),
#  (23537,
#   '2018',
#   'CA',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '8.5',
#   '%'),
#  (23545,
#   '2017',
#   'CA',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '7.8',
#   '%'),
#  (23546,
#   '2011',
#   'AZ',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '9.6',
#   '%'),
#  (23547,
#   '2014',
#   'CA',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '7.8',
#   '%'),
#  (23549,
#   '2018',
#   'CO',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '9.1',
#   '%'),
#  (23553,
#   '2019',
#   'AK',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '9.9',
#   '%'),
#  (23560,
#   '2012',
#   'AZ',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '8.6',
#   '%'),
#  (23562,
#   '2019',
#   'CA',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '7.8',
#   '%'),
#  (23574,
#   '2013',
#   'AK',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '9.4',
#   '%'),
#  (23579,
#   '2017',
#   'AK',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '8.4',
#   '%'),
#  (23580,
#   '2016',
#   'CA',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '7.8',
#   '%'),
#  (23585,
#   '2019',
#   'AR',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '9.3',
#   '%'),
#  (23586,
#   '2018',
#   'AK',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '9',
#   '%'),
#  (23597,
#   '2014',
#   'AZ',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '9.6',
#   '%'),
#  (23598,
#   '2015',
#   'AK',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '9.3',
#   '%'),
#  (23600,
#   '2014',
#   'CO',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '8.4',
#   '%'),
#  (23605,
#   '2012',
#   'MA',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '10.8',
#   '%'),
#  (23613,
#   '2015',
#   'VA',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '7.9',
#   '%'),
#  (23643,
#   '2012',
#   'KY',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '11',
#   '%'),
#  (23671,
#   '2019',
#   'IA',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '8',
#   '%'),
#  (23675,
#   '2015',
#   'WY',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '8',
#   '%'),
#  (23705,
#   '2017',
#   'RI',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '12.3',
#   '%'),
#  (23710,
#   '2013',
#   'WY',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '9.1',
#   '%'),
#  (23721,
#   '2012',
#   'MI',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '10.4',
#   '%'),
#  (23726,
#   '2011',
#   'OR',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '10.4',
#   '%'),
#  (23747,
#   '2019',
#   'MD',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '9',
#   '%'),
#  (23794,
#   '2012',
#   'SC',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '8.7',
#   '%'),
#  (23805,
#   '2016',
#   'NM',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '11.9',
#   '%'),
#  (23844,
#   '2019',
#   'OH',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '11.3',
#   '%'),
#  (23848,
#   '2018',
#   'NM',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '9.6',
#   '%'),
#  (23877,
#   '2013',
#   'IA',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '7.8',
#   '%'),
#  (23888,
#   '2015',
#   'MO',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '9.6',
#   '%'),
#  (23892,
#   '2012',
#   'MS',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '8.1',
#   '%'),
#  (23897,
#   '2015',
#   'MN',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '7.4',
#   '%'),
#  (23909,
#   '2018',
#   'ID',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '8.6',
#   '%'),
#  (23932,
#   '2013',
#   'VA',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '8.6',
#   '%'),
#  (24015,
#   '2019',
#   'KS',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '10',
#   '%'),
#  (24046,
#   '2014',
#   'SC',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '8.3',
#   '%'),
#  (24108,
#   '2015',
#   'MA',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '10.2',
#   '%'),
#  (24122,
#   '2019',
#   'CT',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '10.5',
#   '%'),
#  (24138,
#   '2015',
#   'OH',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '9.9',
#   '%'),
#  (24152,
#   '2013',
#   'OK',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '9',
#   '%'),
#  (24171,
#   '2019',
#   'WV',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '11.6',
#   '%'),
#  (24178,
#   '2019',
#   'NY',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '9.3',
#   '%'),
#  (24186,
#   '2017',
#   'KS',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '9.1',
#   '%'),
#  (24192,
#   '2013',
#   'NY',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '9.7',
#   '%'),
#  (24197,
#   '2015',
#   'OR',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '11.2',
#   '%'),
#  (24223,
#   '2017',
#   'VA',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '8.8',
#   '%'),
#  (24229,
#   '2012',
#   'KS',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '8.4',
#   '%'),
#  (24238,
#   '2016',
#   'MS',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '8',
#   '%'),
#  (24249,
#   '2014',
#   'KY',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '11.9',
#   '%'),
#  (24261,
#   '2011',
#   'IL',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '8.1',
#   '%'),
#  (24292,
#   '2016',
#   'MT',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '8.5',
#   '%'),
#  (24294,
#   '2016',
#   'ME',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '12.2',
#   '%'),
#  (24337,
#   '2011',
#   'WY',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '9.1',
#   '%'),
#  (24353,
#   '2012',
#   'WY',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '9',
#   '%'),
#  (24369,
#   '2017',
#   'MD',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '9.4',
#   '%'),
#  (24382,
#   '2018',
#   'MD',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '9.4',
#   '%'),
#  (24409,
#   '2018',
#   'ME',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '12.3',
#   '%'),
#  (24482,
#   '2012',
#   'WI',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '8.6',
#   '%'),
#  (24498,
#   '2014',
#   'MA',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '12',
#   '%'),
#  (24510,
#   '2011',
#   'KS',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '8.8',
#   '%'),
#  (24528,
#   '2015',
#   'NY',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '9.9',
#   '%'),
#  (24573,
#   '2018',
#   'OK',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '10.4',
#   '%'),
#  (24574,
#   '2011',
#   'RI',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '11.8',
#   '%'),
#  (24600,
#   '2012',
#   'WA',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '9.7',
#   '%'),
#  (24608,
#   '2013',
#   'MD',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '9.4',
#   '%'),
#  (24722,
#   '2011',
#   'MN',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '6.9',
#   '%'),
#  (24770,
#   '2014',
#   'MS',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '7.4',
#   '%'),
#  (24786,
#   '2017',
#   'NY',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '9.1',
#   '%'),
#  (24841,
#   '2014',
#   'WY',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '8.2',
#   '%'),
#  (24844,
#   '2017',
#   'ME',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '11.2',
#   '%'),
#  (24855,
#   '2019',
#   'OK',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '10.2',
#   '%'),
#  (24873,
#   '2011',
#   'MA',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '10.8',
#   '%'),
#  (24881,
#   '2016',
#   'KS',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '8.8',
#   '%'),
#  (24884,
#   '2016',
#   'ID',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '9.2',
#   '%'),
#  (24893,
#   '2013',
#   'KS',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '8.9',
#   '%'),
#  (24940,
#   '2013',
#   'LA',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '7.7',
#   '%'),
#  (24943,
#   '2014',
#   'ID',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '8.7',
#   '%'),
#  (24976,
#   '2011',
#   'MO',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '9.2',
#   '%'),
#  (24982,
#   '2014',
#   'NM',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '10',
#   '%'),
#  (25030,
#   '2016',
#   'MA',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '10.3',
#   '%'),
#  (25039,
#   '2017',
#   'SD',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '7.3',
#   '%'),
#  (25047,
#   '2015',
#   'OK',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '9.5',
#   '%'),
#  (25119,
#   '2015',
#   'RI',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '11',
#   '%'),
#  (25121,
#   '2016',
#   'KY',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '11.5',
#   '%'),
#  (25124,
#   '2011',
#   'NY',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '9.7',
#   '%'),
#  (25127,
#   '2014',
#   'WA',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '9.2',
#   '%'),
#  (25166,
#   '2016',
#   'MD',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '9.5',
#   '%'),
#  (25177,
#   '2014',
#   'KS',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '8.7',
#   '%'),
#  (25188,
#   '2019',
#   'WI',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '10.2',
#   '%'),
#  (25195,
#   '2019',
#   'VA',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '8.8',
#   '%'),
#  (25207,
#   '2016',
#   'SC',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '8.8',
#   '%'),
#  (25210,
#   '2015',
#   'MD',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '8.8',
#   '%'),
#  (25219,
#   '2012',
#   'OK',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '10.1',
#   '%'),
#  (25220,
#   '2017',
#   'MO',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '9.4',
#   '%'),
#  (25242,
#   '2018',
#   'WI',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '9',
#   '%'),
#  (25248,
#   '2012',
#   'PA',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '10.2',
#   '%'),
#  (25253,
#   '2017',
#   'MN',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '7.3',
#   '%'),
#  (25260,
#   '2012',
#   'OR',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '10.6',
#   '%'),
#  (25297,
#   '2016',
#   'OK',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '10',
#   '%'),
#  (25317,
#   '2012',
#   'NC',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '7.7',
#   '%'),
#  (25335,
#   '2011',
#   'NJ',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '9',
#   '%'),
#  (25352,
#   '2017',
#   'OR',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '10.8',
#   '%'),
#  (25375,
#   '2015',
#   'NC',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '8.1',
#   '%'),
#  (25396,
#   '2019',
#   'RI',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '11.2',
#   '%'),
#  (25400,
#   '2015',
#   'WI',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '9.8',
#   '%'),
#  (25411,
#   '2018',
#   'OR',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '11.6',
#   '%'),
#  (25423,
#   '2011',
#   'WV',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '9.1',
#   '%'),
#  (25446,
#   '2012',
#   'IA',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '8',
#   '%'),
#  (25466,
#   '2017',
#   'WI',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '9.7',
#   '%'),
#  (25467,
#   '2014',
#   'MI',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '10.9',
#   '%'),
#  (25494,
#   '2013',
#   'MO',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '10.8',
#   '%'),
#  (25540,
#   '2014',
#   'ME',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '11.6',
#   '%'),
#  (25547,
#   '2013',
#   'WV',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '9',
#   '%'),
#  (25553,
#   '2014',
#   'IA',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '8.5',
#   '%'),
#  (25578,
#   '2019',
#   'MA',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '10.3',
#   '%'),
#  (25589,
#   '2017',
#   'HI',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '9.9',
#   '%'),
#  (25609,
#   '2018',
#   'LA',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '8.9',
#   '%'),
#  (25613,
#   '2018',
#   'ND',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '8.3',
#   '%'),
#  (25621,
#   '2018',
#   'OH',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '9.4',
#   '%'),
#  (25627,
#   '2018',
#   'NH',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '12.4',
#   '%'),
#  (25645,
#   '2019',
#   'MN',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '8.3',
#   '%'),
#  (25647,
#   '2018',
#   'WY',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '8.7',
#   '%'),
#  (25692,
#   '2013',
#   'MN',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '7.7',
#   '%'),
#  (25705,
#   '2015',
#   'IL',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '8.4',
#   '%'),
#  (25708,
#   '2013',
#   'NE',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '7.3',
#   '%'),
#  (25731,
#   '2016',
#   'OH',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '9.7',
#   '%'),
#  (25736,
#   '2017',
#   'WV',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '12.4',
#   '%'),
#  (25756,
#   '2015',
#   'ME',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '11.5',
#   '%'),
#  (25759,
#   '2018',
#   'MS',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '9.7',
#   '%'),
#  (25794,
#   '2017',
#   'IA',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '9.3',
#   '%'),
#  (25826,
#   '2018',
#   'MI',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '11.2',
#   '%'),
#  (25852,
#   '2013',
#   'OH',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '9.7',
#   '%'),
#  (25877,
#   '2013',
#   'ME',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '12.2',
#   '%'),
#  (25887,
#   '2012',
#   'OH',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '10.5',
#   '%'),
#  (25924,
#   '2015',
#   'IA',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '7.6',
#   '%'),
#  (25937,
#   '2015',
#   'HI',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '10.1',
#   '%'),
#  (25966,
#   '2016',
#   'PA',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '10.6',
#   '%'),
#  (26007,
#   '2011',
#   'VA',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '8.7',
#   '%'),
#  (26016,
#   '2015',
#   'WV',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '10.8',
#   '%'),
#  (26053,
#   '2016',
#   'IA',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '7.8',
#   '%'),
#  (26062,
#   '2015',
#   'SD',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '8.4',
#   '%'),
#  (26070,
#   '2012',
#   'NM',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '9.2',
#   '%'),
#  (26078,
#   '2012',
#   'ME',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '11.1',
#   '%'),
#  (26082,
#   '2015',
#   'LA',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '8.1',
#   '%'),
#  (26085,
#   '2013',
#   'RI',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '12',
#   '%'),
#  (26095,
#   '2015',
#   'OR',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '11.4',
#   '%'),
#  (26161,
#   '2011',
#   'PA',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '9',
#   '%'),
#  (26173,
#   '2013',
#   'MA',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '11.5',
#   '%'),
#  (26176,
#   '2016',
#   'VT',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '10.4',
#   '%'),
#  (26188,
#   '2016',
#   'WI',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '8.5',
#   '%'),
#  (26207,
#   '2018',
#   'WA',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '9.4',
#   '%'),
#  (26262,
#   '2011',
#   'LA',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '6.4',
#   '%'),
#  (26273,
#   '2014',
#   'WI',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '10.3',
#   '%'),
#  (26288,
#   '2019',
#   'OR',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '11.2',
#   '%'),
#  (26290,
#   '2015',
#   'NE',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '7.2',
#   '%'),
#  (26294,
#   '2017',
#   'LA',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '9',
#   '%'),
#  (26296,
#   '2014',
#   'DE',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '8.8',
#   '%'),
#  (26302,
#   '2011',
#   'ND',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '7.9',
#   '%'),
#  (26307,
#   '2011',
#   'SD',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '6.9',
#   '%'),
#  (26317,
#   '2017',
#   'OH',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '9.9',
#   '%'),
#  (26364,
#   '2018',
#   'MA',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '10.2',
#   '%'),
#  (26367,
#   '2017',
#   'WY',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '9.1',
#   '%'),
#  (26385,
#   '2012',
#   'MN',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '8',
#   '%'),
#  (26391,
#   '2016',
#   'DE',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '8.5',
#   '%'),
#  (26413,
#   '2018',
#   'KY',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '11.3',
#   '%'),
#  (26419,
#   '2019',
#   'HI',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '9.7',
#   '%'),
#  (26423,
#   '2011',
#   'ME',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '12.4',
#   '%'),
#  (26433,
#   '2019',
#   'ND',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '8.1',
#   '%'),
#  (26437,
#   '2013',
#   'ND',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '8.5',
#   '%'),
#  (26477,
#   '2017',
#   'FL',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '7.5',
#   '%'),
#  (26488,
#   '2011',
#   'MI',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '9.9',
#   '%'),
#  (26498,
#   '2014',
#   'VT',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '11.5',
#   '%'),
#  (26513,
#   '2013',
#   'MD',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '9.5',
#   '%'),
#  (26518,
#   '2014',
#   'NC',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '7.8',
#   '%'),
#  (26537,
#   '2017',
#   'ND',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '8.6',
#   '%'),
#  (26575,
#   '2011',
#   'IA',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '8.3',
#   '%'),
#  (26585,
#   '2011',
#   'OH',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '9.9',
#   '%'),
#  (26616,
#   '2013',
#   'SD',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '7.9',
#   '%'),
#  (26619,
#   '2012',
#   'DE',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '9.9',
#   '%'),
#  (26620,
#   '2019',
#   'LA',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '7.9',
#   '%'),
#  (26628,
#   '2018',
#   'NC',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '9.4',
#   '%'),
#  (26662,
#   '2019',
#   'WY',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '9.5',
#   '%'),
#  (26690,
#   '2015',
#   'TX',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '7.6',
#   '%'),
#  (26749,
#   '2014',
#   'MN',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '8.4',
#   '%'),
#  (26767,
#   '2012',
#   'ID',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '8.4',
#   '%'),
#  (26789,
#   '2017',
#   'MN',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '7.3',
#   '%'),
#  (26806,
#   '2016',
#   'MI',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '10.9',
#   '%'),
#  (26807,
#   '2018',
#   'MT',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '10',
#   '%'),
#  (26808,
#   '2018',
#   'IA',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '7.9',
#   '%'),
#  (26826,
#   '2011',
#   'OK',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '9.6',
#   '%'),
#  (26868,
#   '2011',
#   'MD',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '8.4',
#   '%'),
#  (26876,
#   '2016',
#   'NC',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '8',
#   '%'),
#  (26882,
#   '2017',
#   'MA',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '11.4',
#   '%'),
#  (26915,
#   '2018',
#   'DE',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '10.1',
#   '%'),
#  (26925,
#   '2014',
#   'PA',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '9.8',
#   '%'),
#  (26950,
#   '2018',
#   'PA',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '10',
#   '%'),
#  (26983,
#   '2013',
#   'NC',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '8.4',
#   '%'),
#  (26996,
#   '2014',
#   'OH',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '10.8',
#   '%'),
#  (27015,
#   '2016',
#   'WA',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '9.6',
#   '%'),
#  (27017,
#   '2013',
#   'WI',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '10.6',
#   '%'),
#  (27036,
#   '2015',
#   'ND',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '8.8',
#   '%'),
#  (27039,
#   '2013',
#   'OR',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '11.4',
#   '%'),
#  (27062,
#   '2016',
#   'NH',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '12',
#   '%'),
#  (27065,
#   '2019',
#   'TN',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '8.8',
#   '%'),
#  (27083,
#   '2013',
#   'DC',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '11.9',
#   '%'),
#  (27086,
#   '2016',
#   'KY',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '11.6',
#   '%'),
#  (27091,
#   '2016',
#   'IL',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '8.8',
#   '%'),
#  (27125,
#   '2011',
#   'NE',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '7.3',
#   '%'),
#  (27160,
#   '2012',
#   'NJ',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '8.7',
#   '%'),
#  (27161,
#   '2019',
#   'VA',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '8.8',
#   '%'),
#  (27175,
#   '2012',
#   'OK',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '10.2',
#   '%'),
#  (27190,
#   '2016',
#   'SC',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '8.8',
#   '%'),
#  (27244,
#   '2017',
#   'TX',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '7.3',
#   '%'),
#  (27246,
#   '2019',
#   'FL',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '7.3',
#   '%'),
#  (27273,
#   '2019',
#   'WI',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '10.2',
#   '%'),
#  (27287,
#   '2016',
#   'OR',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '10.5',
#   '%'),
#  (27295,
#   '2014',
#   'NM',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '9.9',
#   '%'),
#  (27297,
#   '2019',
#   'TX',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '7.1',
#   '%'),
#  (27310,
#   '2013',
#   'NV',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '7.5',
#   '%'),
#  (27397,
#   '2015',
#   'OK',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '9.4',
#   '%'),
#  (27412,
#   '2012',
#   'MI',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '10.5',
#   '%'),
#  (27431,
#   '2016',
#   'MD',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '9.4',
#   '%'),
#  (27476,
#   '2017',
#   'SD',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '7.2',
#   '%'),
#  (27491,
#   '2015',
#   'NY',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '9.9',
#   '%'),
#  (27494,
#   '2012',
#   'LA',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '7.4',
#   '%'),
#  (27534,
#   '2013',
#   'SC',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '8.4',
#   '%'),
#  (27564,
#   '2012',
#   'OR',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '10.5',
#   '%'),
#  (27574,
#   '2017',
#   'IL',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '8.2',
#   '%'),
#  (27582,
#   '2017',
#   'NY',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '9.2',
#   '%'),
#  (27617,
#   '2012',
#   'NM',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '9.2',
#   '%'),
#  (27623,
#   '2014',
#   'IL',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '9.1',
#   '%'),
#  (27654,
#   '2014',
#   'VA',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '8.6',
#   '%'),
#  (27656,
#   '2019',
#   'OK',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '10.3',
#   '%'),
#  (27665,
#   '2019',
#   'IL',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '8.2',
#   '%'),
#  (27668,
#   '2014',
#   'WY',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '8.3',
#   '%'),
#  (27684,
#   '2011',
#   'KY',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '10.3',
#   '%'),
#  (27705,
#   '2011',
#   'MA',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '10.7',
#   '%'),
#  (27707,
#   '2017',
#   'TN',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '9.9',
#   '%'),
#  (27727,
#   '2017',
#   'KY',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '10.6',
#   '%'),
#  (27792,
#   '2014',
#   'OR',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '10.2',
#   '%'),
#  (27799,
#   '2011',
#   'NV',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '8',
#   '%'),
#  (27814,
#   '2011',
#   'DC',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '10.1',
#   '%'),
#  (27821,
#   '2014',
#   'KY',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '11.9',
#   '%'),
#  (27837,
#   '2014',
#   'UT',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '8.7',
#   '%'),
#  (27847,
#   '2011',
#   'WI',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '9.3',
#   '%'),
#  (27856,
#   '2017',
#   'NV',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '10.4',
#   '%'),
#  (27882,
#   '2017',
#   'NM',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '10.6',
#   '%'),
#  (27890,
#   '2014',
#   'NY',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '10.7',
#   '%'),
#  (27904,
#   '2017',
#   'VA',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '8.9',
#   '%'),
#  (27917,
#   '2019',
#   'NV',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '9.3',
#   '%'),
#  (27933,
#   '2014',
#   'FL',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '8',
#   '%'),
#  (27949,
#   '2016',
#   'VA',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '8.5',
#   '%'),
#  (27955,
#   '2016',
#   'ME',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '12.7',
#   '%'),
#  (27981,
#   '2019',
#   'WV',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '11.5',
#   '%'),
#  (27989,
#   '2013',
#   'KY',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '9.3',
#   '%'),
#  (27990,
#   '2013',
#   'NM',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '9.2',
#   '%'),
#  (28015,
#   '2016',
#   'NY',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '9.5',
#   '%'),
#  (28049,
#   '2016',
#   'NE',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '8.2',
#   '%'),
#  (28065,
#   '2019',
#   'KS',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '9.9',
#   '%'),
#  (28074,
#   '2012',
#   'NH',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '10.4',
#   '%'),
#  (28080,
#   '2018',
#   'SC',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '9.1',
#   '%'),
#  (28085,
#   '2015',
#   'SC',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '8.2',
#   '%'),
#  (28155,
#   '2013',
#   'VA',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '8.7',
#   '%'),
#  (28181,
#   '2013',
#   'MA',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '11.4',
#   '%'),
#  (28193,
#   '2017',
#   'OK',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '9.7',
#   '%'),
#  (28212,
#   '2017',
#   'SC',
# ...
#   'Age-adjusted Prevalence',
#   '7.7',
#   '%'),
#  (35720,
#   '2012',
#   'MO',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '10.4',
#   '%'),
#  (35722,
#   '2016',
#   'ND',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '9.1',
#   '%'),
#  (35736,
#   '2012',
#   'KS',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '8.5',
#   '%'),
#  (35753,
#   '2011',
#   'OK',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '9.5',
#   '%'),
#  (35773,
#   '2012',
#   'MD',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '9',
#   '%'),
#  (35779,
#   '2017',
#   'CT',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '10.9',
#   '%'),
#  (35807,
#   '2011',
#   'MD',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '8.5',
#   '%'),
#  (35812,
#   '2016',
#   'NH',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '11.4',
#   '%'),
#  (35816,
#   '2015',
#   'MT',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '9',
#   '%'),
#  (35818,
#   '2012',
#   'TN',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '7.7',
#   '%'),
#  (35821,
#   '2018',
#   'MA',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '10.2',
#   '%'),
#  (35900,
#   '2017',
#   'ND',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '8.6',
#   '%'),
#  (35913,
#   '2018',
#   'PA',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '10',
#   '%'),
#  (35929,
#   '2016',
#   'WA',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '9.6',
#   '%'),
#  (35951,
#   '2013',
#   'NC',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '8.4',
#   '%'),
#  (35982,
#   '2019',
#   'HI',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '9.6',
#   '%'),
#  (35995,
#   '2012',
#   'DE',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '10',
#   '%'),
#  (36021,
#   '2017',
#   'WV',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '12.7',
#   '%'),
#  (36028,
#   '2017',
#   'UT',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '8.8',
#   '%'),
#  (36031,
#   '2015',
#   'WA',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '9.3',
#   '%'),
#  (36034,
#   '2018',
#   'IA',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '7.9',
#   '%'),
#  (36035,
#   '2015',
#   'CT',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '10.5',
#   '%'),
#  (36042,
#   '2018',
#   'NC',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '9.4',
#   '%'),
#  (36043,
#   '2018',
#   'HI',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '9.4',
#   '%'),
#  (36056,
#   '2012',
#   'WV',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '10.3',
#   '%'),
#  (36098,
#   '2014',
#   'RI',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '10.8',
#   '%'),
#  (36107,
#   '2019',
#   'ME',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '12.4',
#   '%'),
#  (36112,
#   '2015',
#   'UT',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '9',
#   '%'),
#  (36118,
#   '2013',
#   'CT',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '9.8',
#   '%'),
#  (36135,
#   '2014',
#   'MD',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '8.7',
#   '%'),
#  (36137,
#   '2012',
#   'ID',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '8.5',
#   '%'),
#  (36157,
#   '2019',
#   'OR',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '11.1',
#   '%'),
#  (36172,
#   '2014',
#   'WI',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '10.3',
#   '%'),
#  (36197,
#   '2014',
#   'NV',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '8.1',
#   '%'),
#  (36248,
#   '2011',
#   'ME',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '12',
#   '%'),
#  (36249,
#   '2016',
#   'DE',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '8.7',
#   '%'),
#  (36251,
#   '2019',
#   'ND',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '8.2',
#   '%'),
#  (36265,
#   '2012',
#   'OH',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '10.6',
#   '%'),
#  (36272,
#   '2018',
#   'DE',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '10.3',
#   '%'),
#  (36287,
#   '2013',
#   'ND',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '8.3',
#   '%'),
#  (36298,
#   '2016',
#   'IA',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '7.8',
#   '%'),
#  (36299,
#   '2013',
#   'IA',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '7.8',
#   '%'),
#  (36314,
#   '2012',
#   'RI',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '10.8',
#   '%'),
#  (36334,
#   '2014',
#   'NH',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '10.2',
#   '%'),
#  (36335,
#   '2016',
#   'WV',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '11.8',
#   '%'),
#  (36351,
#   '2014',
#   'OH',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '10.9',
#   '%'),
#  (36374,
#   '2011',
#   'NC',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '8.8',
#   '%'),
#  (36376,
#   '2015',
#   'DE',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '9.2',
#   '%'),
#  (36402,
#   '2015',
#   'ND',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '9',
#   '%'),
#  (36433,
#   '2019',
#   'IA',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '8.1',
#   '%'),
#  (36470,
#   '2016',
#   'WI',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '8.4',
#   '%'),
#  (36487,
#   '2019',
#   'UT',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '9.8',
#   '%'),
#  (36498,
#   '2019',
#   'NH',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '11.3',
#   '%'),
#  (36502,
#   '2016',
#   'TN',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '10.9',
#   '%'),
#  (36503,
#   '2013',
#   'ME',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '11.9',
#   '%'),
#  (36509,
#   '2015',
#   'TX',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '7.4',
#   '%'),
#  (36515,
#   '2012',
#   'ND',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '7.6',
#   '%'),
#  (36582,
#   '2015',
#   'NJ',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '7.3',
#   '%'),
#  (36587,
#   '2018',
#   'NY',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '10.1',
#   '%'),
#  (36596,
#   '2018',
#   'TN',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '9.8',
#   '%'),
#  (36600,
#   '2015',
#   'IA',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '7.6',
#   '%'),
#  (36695,
#   '2015',
#   'NH',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '10.5',
#   '%'),
#  (36725,
#   '2018',
#   'LA',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '8.9',
#   '%'),
#  (36735,
#   '2015',
#   'WV',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '10.8',
#   '%'),
#  (36763,
#   '2016',
#   'MO',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '9.9',
#   '%'),
#  (36764,
#   '2016',
#   'OH',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '9.7',
#   '%'),
#  (36779,
#   '2013',
#   'MT',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '8.6',
#   '%'),
#  (36787,
#   '2018',
#   'NH',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '11.8',
#   '%'),
#  (36797,
#   '2018',
#   'WY',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '8.7',
#   '%'),
#  (36805,
#   '2017',
#   'IA',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '9.3',
#   '%'),
#  (36824,
#   '2013',
#   'MN',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '7.7',
#   '%'),
#  (36860,
#   '2014',
#   'ND',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '8.9',
#   '%'),
#  (36880,
#   '2015',
#   'ME',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '11.2',
#   '%'),
#  (36883,
#   '2012',
#   'HI',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '8.9',
#   '%'),
#  (36901,
#   '2014',
#   'WV',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '11',
#   '%'),
#  (36906,
#   '2011',
#   'DE',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '9.8',
#   '%'),
#  (36932,
#   '2015',
#   'PA',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '10.2',
#   '%'),
#  (36933,
#   '2017',
#   'NJ',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '8.4',
#   '%'),
#  (36964,
#   '2013',
#   'DE',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '10.6',
#   '%'),
#  (36967,
#   '2014',
#   'TN',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '8.9',
#   '%'),
#  (36972,
#   '2015',
#   'NC',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '8.2',
#   '%'),
#  (36975,
#   '2011',
#   'ID',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '9.2',
#   '%'),
#  (36979,
#   '2011',
#   'WA',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '9.7',
#   '%'),
#  (37003,
#   '2011',
#   'ND',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '8.1',
#   '%'),
#  (37007,
#   '2014',
#   'DE',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '8.7',
#   '%'),
#  (37009,
#   '2012',
#   'IA',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '8.1',
#   '%'),
#  (37020,
#   '2017',
#   'NH',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '13.5',
#   '%'),
#  (37021,
#   '2019',
#   'GA',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '7.7',
#   '%'),
#  (37028,
#   '2017',
#   'PA',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '10.1',
#   '%'),
#  (37104,
#   '2016',
#   'PA',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '10.7',
#   '%'),
#  (37106,
#   '2017',
#   'DE',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '10.6',
#   '%'),
#  (37125,
#   '2014',
#   'IA',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '8.5',
#   '%'),
#  (37130,
#   '2013',
#   'NJ',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '9',
#   '%'),
#  (37138,
#   '2013',
#   'MO',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '10.9',
#   '%'),
#  (37142,
#   '2014',
#   'DC',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '11.3',
#   '%'),
#  (37161,
#   '2017',
#   'HI',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '9.8',
#   '%'),
#  (37163,
#   '2019',
#   'SD',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '8.5',
#   '%'),
#  (37197,
#   '2018',
#   'OH',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '9.6',
#   '%'),
#  (37200,
#   '2014',
#   'PA',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '9.9',
#   '%'),
#  (37214,
#   '2013',
#   'PA',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '9.6',
#   '%'),
#  (37224,
#   '2019',
#   'MN',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '8.3',
#   '%'),
#  (37230,
#   '2017',
#   'WA',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '10.7',
#   '%'),
#  (37238,
#   '2016',
#   'DC',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '10.1',
#   '%'),
#  (37248,
#   '2017',
#   'CT',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '10.7',
#   '%'),
#  (37257,
#   '2011',
#   'NH',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '11',
#   '%'),
#  (37262,
#   '2019',
#   'PA',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '10.9',
#   '%'),
#  (37265,
#   '2011',
#   'UT',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '8.7',
#   '%'),
#  (37276,
#   '2012',
#   'VT',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '11.2',
#   '%'),
#  (37297,
#   '2018',
#   'MS',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '9.6',
#   '%'),
#  (37299,
#   '2017',
#   'GA',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '8.4',
#   '%'),
#  (37317,
#   '2012',
#   'MD',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '9.1',
#   '%'),
#  (37320,
#   '2011',
#   'MT',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '9.4',
#   '%'),
#  (37329,
#   '2017',
#   'OR',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '10.8',
#   '%'),
#  (37353,
#   '2015',
#   'KS',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '8.6',
#   '%'),
#  (37369,
#   '2011',
#   'NJ',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '9',
#   '%'),
#  (37410,
#   '2014',
#   'HI',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '9.2',
#   '%'),
#  (37426,
#   '2018',
#   'MO',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '9.5',
#   '%'),
#  (37440,
#   '2011',
#   'WV',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '9.2',
#   '%'),
#  (37524,
#   '2013',
#   'ID',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '8.7',
#   '%'),
#  (37536,
#   '2019',
#   'NC',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Age-adjusted Prevalence',
#   '8.2',
#   '%'),
#  (37550,
#   '2014',
#   'MO',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '9.7',
#   '%'),
#  (37551,
#   '2013',
#   'WV',
#   'Current asthma prevalence among adults aged >= 18 years',
#   'Crude Prevalence',
#   '9',
#   '%')]

# %% [markdown]
# # ETL of [Air Data](https://www.epa.gov/outdoor-air-quality-data)

# %%
#finding the name of all the files in the air quality folder
all_files = glob.glob('./Air_quality_csv/*.csv')

air_list = []
#reading all the CSV files
for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    air_list.append(df)
#creating the concatenated dataframe
air_df = pd.concat(air_list, axis=0, ignore_index=True)

# %%
air_df

# %%
# there is the need to aggregate the data by state and year
# The output is the average number of days that were over the law limits per parameter of interest (i.e. PMx)
# The average median and maximum API per state in a year is evaluated as well.
aggregate_air_df = air_df.groupby(by=['State','Year']).mean()
air_df = aggregate_air_df.reset_index()

# %%
#printing the names of the dataframe columns
air_df.columns

# %%
#dropping not useful column 
columns_to_drop = ['Days with AQI',\
                   'Good Days',\
                   'Moderate Days',\
                   'Unhealthy for Sensitive Groups Days',\
                   'Unhealthy Days',\
                   'Very Unhealthy Days',\
                   'Hazardous Days',\
                   '90th Percentile AQI',
                   'Days CO',\
                   'Days NO2',\
                   'Days SO2',]
air_df=air_df.drop(columns=columns_to_drop)

# %%
air_df

# %%
#converting the number of days in integers because as float they do not make too much sense
for column in air_df.columns:
    if air_df[column].dtype == float:
        air_df[column]= air_df[column].astype('int64')

# %%
# adding collection about asthma to sqlite
add_table_to_db('air', air_df, conn)

# %%
#removing the point from the key for handling the dataset in MongoDb without issues
air_df=air_df.rename(columns={"Days PM2.5": "Days PM2_5"})
air_df

# %%
# adding collection about asthma to MongoDB
add_collection_to_mongo('air',air_df)

# %%
#closing the connections to sqlite and MongoDB
conn.close()
mongo_client.close()
